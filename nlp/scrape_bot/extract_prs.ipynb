# %%
import glob 
import os
import re
import json
import shutil
import pandas as pd
from bs4 import BeautifulSoup

# %%
def item_filter_2(tag):
    cond = tag.name == 'li'
    cond = cond and tag.find('a').get('href')
    cond = cond and 'pull' in cond.split('/')[-2] # look for Git pull requests
    return cond

# %%
def extract_state(row):
    symbol = [sym for sym in state_symbols if (sym in row)]
    if len(symbol) == 1:
        return state_map[symbol[0]]
    return ''

state_map = {
    '⚠': 'wip',
    '👀': 'needs review',
    '✔': 'done',
}

state_symbols = list(state_map.keys())

# %%
def extract_contributors(text):
    contributors = text.split('(')[-1].split(')')[0]
    if text == contributors:
        return ''
    return contributors

# %%
def clean_2(text):

    text = text.split(' ') # split text on spaces
    for t in text:
        # remove any state symbols
        if any (sym in t for sym in state_symbols):
            text.remove(t)
    
    del text[-1] # remove contributor 
    text = ' '.join(text) # join back into single string
    # Remove square brackets and anything inside
    pattern = r'\[.*?\]'
    text = re.sub(pattern, '', text)
    # Remove any token with '#'
    text = " ".join(filter(lambda x:x[0]!='#', text.split()))
    # Remove any 'PR'
    text = text.replace('PR', "")

    return text

# %%
def clean_file(filename):
    print(filename)
    with open(filename) as f:
        data = json.load(f)
                
    soup = BeautifulSoup(data['full'], 'html.parser')
    
    data = []
    for it in soup.find_all(item_filter_2):
        data.append({
            'text': it.text,
            'link': it.find('a').get('href'),
        })
    df = pd.DataFrame(data)
    
    df['state'] = df.text.apply(extract_state)

    df['contributors'] = df.text.apply(extract_contributors)

    df['text_cleaned'] = df.text.apply(clean_2)
    
    df.to_csv(r'./scraped_prs/aggregate_prs.csv'.format(filename.split('/')[-1]), header=True, index=None, mode='a')
    
    return df

# %%
# Main
success_c = 0
for filename in glob.glob('./scraped_raw/*.json'):
    try: 
        df = clean_file(filename)
        success_c += 1 
    except:
        print('failed')
        # Quarantine failures
        shutil.move(filename, './quarantine/')
        pass
# Out:
# ./scraped_raw/DATA Digest from Mon, Jan 04 to Sun, Jan 10, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Feb 02 to Mon, Feb 8, 2021.json
# ./scraped_raw/DATA Digest - Mon, Mar 08 to Sun, Mar 14, 2021.json
# ./scraped_raw/DATA Digest from Mon, Jan 18 to Sun, Jan 24, 2021.json
# ./scraped_raw/DATA Digest - Mon, May 03 to Sun, May 9, 2021.json
# ./scraped_raw/DATA Digest - Mon, Mar 01 to Sun, Mar 7, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Jan 05 to Mon, Jan 11, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Jan 19 to Mon, Jan 25, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, May 18 to Mon, May 24, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, May 04 to Mon, May 10, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Dec 15 to Mon, Dec 21, 2020.json
# ./scraped_raw/DATA Digest - Mon, Apr 12 to Sun, Apr 18, 2021.json
# ./scraped_raw/DATA Digest - Mon, Feb 22 to Sun, Feb 28, 2021.json
# ./scraped_raw/DATA Digest from Mon, Dec 14 to Sun, Dec 20, 2020.json
# ./scraped_raw/PRODUCT Digest from Tue, Dec 22 to Mon, Dec 28, 2020.json
# ./scraped_raw/Dev Digest - from Tue, Dec 08 to Mon, Dec 14, 2020.json
# ./scraped_raw/PRODUCT Digest from Tue, Jan 26 to Mon, Feb 1, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, May 25 to Mon, May 31, 2021.json
# ./scraped_raw/DATA Digest - Mon, Mar 22 to Sun, Mar 28, 2021.json
# ./scraped_raw/DATA Digest - Mon, May 31 to Sun, Jun 6, 2021.json
# ./scraped_raw/DATA Digest from Mon, Jan 25 to Sun, Jan 31, 2021.json
# ./scraped_raw/DATA Digest - Mon, Apr 26 to Sun, May 2, 2021.json
# ./scraped_raw/DATA Digest - Mon, Mar 15 to Sun, Mar 21, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Apr 06 to Mon, Apr 12, 2021.json
# ./scraped_raw/DATA Digest from Mon, Jan 11 to Sun, Jan 17, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, May 11 to Mon, May 17, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Apr 20 to Mon, Apr 26, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Mar 30 to Mon, Apr 5, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Mar 09 to Mon, Mar 15, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Dec 29, 2020 to Mon, Jan 4, 2021.json
# ./scraped_raw/DATA Digest - Mon, May 17 to Sun, May 23, 2021.json
# ./scraped_raw/DATA Digest from Mon, Dec 21 to Sun, Dec 27, 2020.json
# ./scraped_raw/PRODUCT Digest - Tue, Mar 02 to Mon, Mar 8, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Apr 13 to Mon, Apr 19, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Mar 16 to Mon, Mar 22, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Feb 23 to Mon, Mar 1, 2021.json
# ./scraped_raw/PRODUCT Digest from Tue, Jan 12 to Mon, Jan 18, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Apr 27 to Mon, May 3, 2021.json
# ./scraped_raw/PRODUCT Digest - Tue, Mar 23 to Mon, Mar 29, 2021.json
# ./scraped_raw/DATA Digest - Mon, May 24 to Sun, May 30, 2021.json
# ./scraped_raw/DATA Digest - Mon, May 10 to Sun, May 16, 2021.json
# ./scraped_raw/Dev Digest - from Mon, Nov 23 to Mon, Nov 30, 2020.json
# ./scraped_raw/DATA Digest from Mon, Feb 01 to Sun, Feb 7, 2021.json
# ./scraped_raw/DATA Digest - Mon, Mar 29 to Sun, Apr 4, 2021.json
# ./scraped_raw/DATA Digest from Mon, Dec 28, 2020 to Sun, Jan 3, 2021.json
# ./scraped_raw/DATA Digest - Mon, Apr 05 to Sun, Apr 11, 2021.json
# ./scraped_raw/DATA Digest - Mon, Apr 19 to Sun, Apr 25, 2021.json

# %%
# Display
pd.set_option('display.max_rows', None)

print('Cleaned {} out of {} files.'.format(success_c, len(list(os.listdir('./scraped_raw/')))))
df = pd.read_csv('./scraped_prs/aggregate_prs.csv')
df
# Out:
# Cleaned 47 out of 47 files.
#                                                    text  \
# 0     👀 PR #68 Bday sign fix multi-bday logic (tlowa...
# 1     ✔️ PR #67 diff - incorporate @eqworks/release ...
# 2     ✔️ PR #64 Notes - make slack message link flex...
# 3     ✔️ PR #63 devops - yarn upgrade-interactive 20...
# 4     ✔️ PR #9 github - include lone repo updates (s...
# 5          👀 PR #10 Weilin test/supun 1 (wwwmonsterlam)
# 6        👀 PR #9 Google analytics supun (wwwmonsterlam)
# 7     ✔️ PR #8 Google analytics - Handling multiple ...
# 8     ✔️ PR #24 enrich_demographic - fix check of da...
# 9     ✔️ PR #23 get_polygon - fix geometry without d...
# 10    ✔️ PR #22 enrich_demographic - add flag for fs...
# 11    ✔️ PR #21 get_hh_data - delete ip when existin...
# 12    ✔️ PR #20 Round value to nearest integer when ...
# 13    ✔️ PR #19 Add billing for getting AOI data (ma...
# 14          ✔️ PR #18 Device/hh enrichment (bsandi1220)
# 15              👀 PR #44 Access hub datasets (maluhoss)
# 16               ✔️ PR #43 Enrich/hh graph (bsandi1220)
# 17              ✔️ PR #42 Enrich by distance (maluhoss)
# 18    ✔️ PR #33 Add prompt for billing for getting A...
# 19    👀 PR #25 Dev journal - update with asana autom...
# 20    👀 PR #24 update documentation with bday, demo ...
# 21    👀 PR #23 meetings - update with recent progres...
# 22    ✔️ PR #22 git - add another way to solve rebas...
# 23    ✔️ PR #21 git - agnostic main branch, rev on c...
# 24                 ✔️ PR #15 Communication (Goondrious)
# 25    ✔️ PR #14 Revised Communication Doc: Includes ...
# 26    ✔️ PR #10 Reviewed and made a quick draft of t...
# 27    ✔️ PR #1 devops - port from @eqworks/react-lab...
# 28    👀 PR #6 02 - logic controls (bitwise operation...
# 29    ✔️ PR #5 02 - logic controls (conditions, bool...
# 30    ⚠️ PR #1 Dashboard layout base structure (DoPa...
# 31    ⚠️ PR #10 ip/eval meta and ip unary clustering...
# 32    ✔️ PR #2 Airflow/clustering pipeline (bsandi1220)
# 33    ✔️ PR #2 get_location_segments - return empty ...
# 34    👀 PR #28 Shortest path phase2 boxgen (tris-olson)
# 35    👀 PR #24 airflowize daily commute and commute ...
# 36                                                 text
# 37    👀 PR #56 Updated design role evaluation criter...
# 38    ⚠️ PR #68 widgets playground - flow selector f...
# 39    ⚠️ PR #67 Pro mode - support query create/edit...
# 40                     ⚠️ PR #10 ff - outro (woozyking)
# 41    ✔️ PR #9 03 - 3/3 classes, pandas (dataframes)...
# 42    👀 PR #12 Upgrade @material-ui, @eqworks/lumen-...
# 43    ✔️ PR #11 consistent filter position in a smal...
# 44    ✔️ PR #9 Enable table heads to take a fixed am...
# 45                  ⚠️ PR #52 Package change (geoerika)
# 46    ✔️ PR #51 Upgrade material-ui, react-maps; rep...
# 47             ⚠️ PR #31 Material UI upgrade (geoerika)
# 48      ✔️ PR #5 Package - changed to v1.0.1 (geoerika)
# 49    ✔️ PR #4 Upgrade material-ui packages; fix war...
# 50    ✔️ PR #58 Material-ui upgrade; replace react-l...
# 51        ✔️ PR #2 API endpoints meta table (woozyking)
# 52      ✔️ PR #933 builder - upgrade version (tlowande)
# 53    ✔️ PR #932 Home - read wl/cu from url and popu...
# 54    ✔️ PR #931 builder - hide preprocess jobs view...
# 55    ✔️ PR #928 Finance - smaug daily API consumpti...
# 56    👀 PR #13 Google analytics 4 connector (supunte...
# 57                👀 PR #11 Supun tests (supuntennakoon)
# 58      ✔️ PR #9 Google analytics supun (wwwmonsterlam)
# 59                     ✔️ PR #7 User scope (dilanSuraj)
# 60    ✔️ PR #56 Feature/native df compatibility (bsa...
# 61    ✔️ PR #55 Feature/native df compatibility (bsa...
# 62    👀 PR #54 Save dataset as hub connection (maluh...
# 63    ✔️ PR #53 AOI - Change routes to use query par...
# 64    ✔️ PR #52 create_segment - add method to proce...
# 65              ✔️ PR #51 Add Geocoding Util (maluhoss)
# 66    ✔️ PR #16 devops -update notebook image (bsand...
# 67    ✔️ PR #24 flow/utils - support lookalike segme...
# 68                    ✔️ PR #20 Exp autosize (DoParkEQ)
# 69    ✔️ PR #495 Use query params instead of route p...
# 70            ✔️ PR #494 Add geocoding route (maluhoss)
# 71    ✔️ PR #493 expense - smaug daily report split ...
# 72    ✔️ PR #28 popular times - refactor segment to ...
# 73                    ⚠️ PR #5 widget editor (DoParkEQ)
# 74                    👀 PR #14 Asana/vacays (woozyking)
# 75    ⚠️ PR #69 journal - setup asana oauth flow via...
# 76    ⚠️ PR #1 Create new note in Hugo meetings with...
# 77    ✔️ PR #33 common/baseHandler - filter out reve...
# 78     ⚠️ PR #32 nlp/label - 2021-Feb batch (woozyking)
# 79                  ⚠️ PR #1803 LocusPOI fix (geoerika)
# 80                                                 text
# 81    👀 PR #122 data - add Pandas variant, revise in...
# 82    ✔️ PR #114 mobile - open options to use stacks...
# 83    👀 PR #113 product - re-org tracks and revise p...
# 84    ✔️ PR #1 devops/gltich - update install instru...
# 85                       ✔️ PR #3 My branch (warrenchu)
# 86    👀 PR #2 docker - use jupyter/pyspark-notebook ...
# 87     ✔️ PR #185 Fix/sdr preprocess oom (QingleiZhang)
# 88       👀 PR #12 Bell test final filter (QingleiZhang)
# 89     👀 PR #11 Bell test data clean (steven-mindswire)
# 90                👀 PR #9 add README.md (wwwmonsterlam)
# 91    ⚠️ PR #22 popular times v1 - remove preprocess...
# 92                  👀 PR #1 Step fn migration (odesiuz)
# 93      👀 PR #63 AOI - Improve fetching data (maluhoss)
# 94    ✔️ PR #60 enrich - update direct mapping to us...
# 95    ✔️ PR #62 get_popular_times - remove suppport ...
# 96    ✔️ PR #61 get_geojson - add presigned post url...
# 97        👀 PR #31 AOI - improve scalability (maluhoss)
# 98    ✔️ PR #30 get_geojson - update to use presigne...
# 99    ✔️ PR #29 get_presigned_post - add upload type...
# 100   ✔️ PR #7 demo - remove popular-times-v1 (bsand...
# 101   👀 PR #23 popular-times-v1 - remove API backend...
# 102   👀 PR #4 Shopify - Endpoints for the Events Sec...
# 103   👀 PR #3 Shopify - Endpoints for the Inventory ...
# 104   👀 PR #2 Shopify - Endpoints for the Orders sec...
# 105   👀 PR #1 Shopify - Endpoints for the Products s...
# 106   ✔️ PR #19 devops - update notebook image (bsan...
# 107          ✔️ PR #14 06 - meta-automation (woozyking)
# 108          👀 PR #35 Bert embedding (steven-mindswire)
# 109    ✔️ PR #32 nlp/label - 2021-Feb batch (woozyking)
# 110            👀 PR #5 Hivestack index filter (odesiuz)
# 111                   ⚠️ PR #4 Index Job (QingleiZhang)
# 112                                                text
# 113   ⚠️ PR #8 03 dict, while, loop controls, time-c...
# 114   ✔️ PR #7 03 - data containers and repetitions ...
# 115   ⚠️ PR #1 Query mechanism and daily finance agg...
# 116   ⚠️ PR #125 experiment on visx/d3 integration (...
# 117   ✔️ PR #50 get_dataset - fix aoi storage includ...
# 118   ✔️ PR #49 get_audience_from_poi_list - add met...
# 119   ✔️ PR #48 poi - add get_avail_poi_lists and ge...
# 120   ✔️ PR #22 audience build - update dynamodb tab...
# 121       ✔️ PR #25 hh - update fernet key (bsandi1220)
# 122   ✔️ PR #15 devops -update notebook image (bsand...
# 123      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 124   👀 PR #3 Clustering pipeline/add polygon (bsand...
# 125   ⚠️ PR #21 Popular times v2/dynamodb upload (bs...
# 126   ✔️ PR #20 count_devices - fix dataframe struct...
# 127   ✔️ PR #19 Update - Add device capture and expo...
# 128   ⚠️ PR #10 ip/eval meta and ip unary clustering...
# 129   ✔️ PR #17 dev-journal - filter undefined value...
# 130   ✔️ PR #13 github - dedupe PR co-committers lis...
# 131   ✔️ PR #12 Range for monthly and annual digest,...
# 132   ✔️ PR #31 tag - make access to package.json sa...
# 133      ✔️ PR #49 Fix/Vast - Fix banner code (kevlabs)
# 134   👀 PR #30 update master branch with in-producti...
# 135   ✔️ PR #29 update shortest_path with wrapper fi...
# 136   ✔️ PR #24 airflowize daily commute and commute...
# 137                   ⚠️ PR #4 Index Job (QingleiZhang)
# 138                👀 PR #3 Commute direction (dshparyk)
# 139                                                text
# 140   ✔️ PR #128 Tooltip disable title prop; add box...
# 141            ⚠️ PR #126 VISX/Plotly/D3 exp (DoParkEQ)
# 142   ✔️ PR #18 others/git - intro to git, commits, ...
# 143               ✔️ PR #1 Ongoing projects (woozyking)
# 144   ✔️ PR #2 Add work sample solution 1-3 (woozyking)
# 145   ✔️ PR #1 recipe - search available POI lists b...
# 146   👀 PR #24 Devops - update notebook image to v0....
# 147   ✔️ PR #23 single user server - fix poststart h...
# 148   👀 PR #80 Devops - add automated testing for de...
# 149                              ✔️ PR #78 get_audience
# 150   ✔️ PR #79 Geocode - fix missing postalcodes du...
# 151   ✔️ PR #46 connection-hub - datetime serializat...
# 152   ✔️ PR #45 connectionHub - datetime serializati...
# 153   ✔️ PR #44 Revert "[G2M] connectionHub - dateti...
# 154   ✔️ PR #42 connectionHub - datetime serializati...
# 155   ✔️ PR #43 Get_polygon - include centroid to us...
# 156   ✔️ PR #651 Customer/GeoCohort - Add cohort siz...
# 157   ✔️ PR #650 insights - geo cohort - add list na...
# 158   ✔️ PR #649 WL - endpoint to create white label...
# 159   👀 PR #35 small fix to journey builder to lower...
# 160        👀 PR #2 Ip classification (steven-mindswire)
# 161    👀 PR #1 restructure and amend doc (QingleiZhang)
# 162                                                text
# 163   👀 PR #114 mobile - open options to use stacks ...
# 164   👀 PR #113 product - re-org tracks and revise p...
# 165   ✔️ PR #112 mobile - update prob 1 for variants...
# 166   ✔️ PR #107 mobile - draft problems and evaluat...
# 167          👀 PR #105 update wireframe link (DoParkEQ)
# 168   ✔️ PR #2 playground - parity with kotlin varia...
# 169   ✔️ PR #1 playground - simplify and factor out ...
# 170   👀 PR #1 Shopify - Endpoints for the Products s...
# 171   👀 PR #60 enrich - update direct mapping to use...
# 172   👀 PR #29 get_presigned_post - add upload type ...
# 173        👀 PR #14 Supun test/supun 7 (supuntennakoon)
# 174   👀 PR #13 Google analytics 4 connector (supunte...
# 175   ✔️ PR #13 05 - add README entry to nbviewer, a...
# 176   ✔️ PR #12 05 - obtain internet resources (wooz...
# 177   ✔️ PR #32 rearranged repo and improved documen...
# 178   👀 PR #30 update master branch with in-producti...
# 179   ✔️ PR #28 Shortest path phase2 boxgen (tris-ol...
# 180   ✔️ PR #7 create_dag - update board mapping and...
# 181    ✔️ PR #6 Daily pipeline/add commute (bsandi1220)
# 182   ⚠️ PR #2 GitHub workflows setup; refactor file...
# 183                                                text
# 184   👀 PR #68 Bday sign fix multi-bday logic (tlowa...
# 185   ✔️ PR #67 diff - incorporate @eqworks/release ...
# 186   ✔️ PR #64 Notes - make slack message link flex...
# 187   ✔️ PR #63 devops - yarn upgrade-interactive 20...
# 188   👀 PR #10 github - lone repo updates to factor ...
# 189   ✔️ PR #9 github - include lone repo updates (s...
# 190   ✔️ PR #14 devJournal/name - fix incremental sp...
# 191   👀 PR #3 offWeekDaysDurations and support unava...
# 192   ✔️ PR #152 [2.0] Remove MUIChip lowercase text...
# 193   ✔️ PR #150 Button - remove children requiremen...
# 194   ✔️ PR #148 Tabs - add vertical tabs option + r...
# 195   👀 PR #147 alert - simplify alert and eliminate...
# 196   ✔️ PR #145 devops - release workflow rev and C...
# 197   👀 PR #52 Ml model/refactor - refactor useMLMod...
# 198   ✔️ PR #51 Nav control - control top & left nav...
# 199                ✔️ PR #50 Files/restructure (hyx131)
# 200   ✔️ PR #49 query-builder/views - persist subvie...
# 201   ✔️ PR #26 meetings - guideline with link to /n...
# 202   ✔️ PR #25 Dev journal - update with asana auto...
# 203   ✔️ PR #24 update documentation with bday, demo...
# 204   ✔️ PR #23 meetings - update with recent progre...
# 205   ✔️ PR #22 git - add another way to solve rebas...
# 206   ✔️ PR #21 git - agnostic main branch, rev on c...
# 207                ✔️ PR #15 Communication (Goondrious)
# 208   ✔️ PR #14 Revised Communication Doc: Includes ...
# 209   ✔️ PR #10 Reviewed and made a quick draft of t...
# 210             👀 PR #46 Update map packages (geoerika)
# 211   ⚠️ PR #42 V1 - research mapbox attribution err...
# 212   👀 PR #41 ColumnPOI - adjust POIManage to lates...
# 213   ✔️ PR #1 devops - port from @eqworks/react-lab...
# 214   👀 PR #6 02 - logic controls (bitwise operation...
# 215   ✔️ PR #5 02 - logic controls (conditions, bool...
# 216      ✔️ PR #48 Fix/Vast - Fix date string (kevlabs)
# 217    ✔️ PR #1800 fix chart rendering issue (tlowande)
# 218   ✔️ PR #1799 Mapbox - update css file for mapbo...
# 219   ✔️ PR #1797 Update poi-manage to v0.4.0 (geoer...
# 220   ✔️ PR #844 Fix/Adserver - Click tracker in cli...
# 221        👀 PR #10 Weilin test/supun 1 (wwwmonsterlam)
# 222      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 223   ✔️ PR #8 Google analytics - Handling multiple ...
# 224   ✔️ PR #24 enrich_demographic - fix check of da...
# 225   ✔️ PR #23 get_polygon - fix geometry without d...
# 226   ✔️ PR #22 enrich_demographic - add flag for fs...
# 227   ✔️ PR #21 get_hh_data - delete ip when existin...
# 228   ✔️ PR #20 Round value to nearest integer when ...
# 229   ✔️ PR #19 Add billing for getting AOI data (ma...
# 230         ✔️ PR #18 Device/hh enrichment (bsandi1220)
# 231             👀 PR #44 Access hub datasets (maluhoss)
# 232              ✔️ PR #43 Enrich/hh graph (bsandi1220)
# 233   ✔️ PR #33 Add prompt for billing for getting A...
# 234   ✔️ PR #485 devops - pin down to node 12.x to m...
# 235   ✔️ PR #484 dataset - add route for household e...
# 236                    ✔️ PR #911 Mapbox fix (geoerika)
# 237   ✔️ PR #910 Update poi-manage to v0.4.0 (geoerika)
# 238      ✔️ PR #908 - new marketplace update (DoParkEQ)
# 239   ⚠️ PR #1 Dashboard layout base structure (DoPa...
# 240                                                text
# 241                 ✔️ PR #1 Port/react labs (tlowande)
# 242                      👀 PR #155 Extracted (tlowande)
# 243                    👀 PR #62 Test release (tlowande)
# 244        👀 PR #61 Widgets playground setup (tlowande)
# 245                      ⚠️ PR #60 Query/saved (hyx131)
# 246     👀 PR #59 bump version to0.3.0-alpha (eq-ianecc)
# 247                 ✔️ PR #58 House cleaning (tlowande)
# 248   ✔️ PR #57 query-builder - fix top drawer posit...
# 249   ⚠️ PR #8 03 dict, set, while, loop controls, t...
# 250   ✔️ PR #7 03 - data containers and repetitions ...
# 251   ⚠️ PR #1 Query mechanism and daily finance agg...
# 252   ✔️ PR #7 devops - replace react-labs with lume...
# 253   ✔️ PR #49 Add productHeightRemove prop to Glob...
# 254   ✔️ PR #48 Error display change in POICard; che...
# 255   ✔️ PR #47 Fix SearchList in GlobalPOIs (geoerika)
# 256   ✔️ PR #55 Map render conditions; upgrade deck....
# 257   👀 PR #4 dashboard & widget base structure (DoP...
# 258      ✔️ PR #3 dashboard widget structure (DoParkEQ)
# 259   ✔️ PR #50 get_dataset - fix aoi storage includ...
# 260   ✔️ PR #49 get_audience_from_poi_list - add met...
# 261   ✔️ PR #48 poi - add get_avail_poi_lists and ge...
# 262   👀 PR #919 design - change illustrations in hom...
# 263   ✔️ PR #918 Upgrade @eqworks/poi-manage to v0.4...
# 264   👀 PR #914 hub - new google sheets flow (woozyk...
# 265   ✔️ PR #22 audience build - update dynamodb tab...
# 266       ✔️ PR #25 hh - update fernet key (bsandi1220)
# 267   👀 PR #489 hub - google sheet connector (eq-ian...
# 268      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 269   ✔️ PR #17 dev-journal - filter undefined value...
# 270   ✔️ PR #13 github - dedupe PR co-committers lis...
# 271   ✔️ PR #12 Range for monthly and annual digest,...
# 272   ✔️ PR #1802 Add mapbox-gl-draw.css stylesheet ...
# 273   ✔️ PR #1801 Upgrade @eqworks/poi-manage to v0....
# 274   👀 PR #1796 Integrate new poi-manage; replace s...
# 275      ✔️ PR #49 Fix/Vast - Fix banner code (kevlabs)
# 276                                                text
# 277   👀 PR #1 Hubspot - Endpoints for the CRM (supun...
# 278   👀 PR #12 Bugfix/exception detection (wwwmonste...
# 279   👀 PR #2 Shopify - Endpoints for the Orders sec...
# 280   ✔️ PR #956 ql - upgrade package with v1.1.0 re...
# 281   ✔️ PR #81 Dataset - get Marketplace layers (ma...
# 282   👀 PR #80 Devops - add automated testing for de...
# 283         ✔️ PR #47 Get Marketplace Layers (maluhoss)
# 284   ✔️ PR #131 package - change version to 0.4.2 (...
# 285   ✔️ PR #130 Tooltip - set notitle as string; ad...
# 286       ✔️ PR #21 11 - work with SQL(ite) (woozyking)
# 287                      👀 PR #74 trips map (eq-ianecc)
# 288   ✔️ PR #73 GeoCohortMp - add reportFSAData,  re...
# 289              👀 PR #94 Categories/re layout (hyx131)
# 290   👀 PR #58 login - send OTP email to registered ...
# 291         ✔️ PR #57 devops - CI revisions (woozyking)
# 292   ✔️ PR #1825 GeoCohort - hide geocohorts for ex...
# 293            👀 PR #1808 geo cohort/reports (DoParkEQ)
# 294   ✔️ PR #2 add color and prefix to verbose msgs,...
# 295   ✔️ PR #1 commit-watch - for commit msg gatekee...
# 296            👀 PR #4 losses visualization (woozyking)
# 297   ✔️ PR #1 port - tensorflow playground simulati...
# 298                                                text
# 299   👀 PR #1 port - tensorflow playground simulatio...
# 300   ✔️ PR #128 Tooltip disable title prop; add box...
# 301            ⚠️ PR #126 VISX/Plotly/D3 exp (DoParkEQ)
# 302   👀 PR #2 projects - add Geo Cohort project/team...
# 303               ✔️ PR #1 Ongoing projects (woozyking)
# 304   ✔️ PR #55 sql - update schema on prefix column...
# 305      👀 PR #21 Incorporate lumen-ui theme (kc-leung)
# 306   ✔️ PR #18 others/git - intro to git, commits, ...
# 307     ✔️ PR #15 package - change to v1.1.1 (kc-leung)
# 308          ✔️ PR #14 Checkbox & Button fix (kc-leung)
# 309   ✔️ PR #72 Fix colour for layer when we have bo...
# 310   ✔️ PR #71 Legend scale fix for zero max; renam...
# 311                     👀 PR #90 Nav/execution (hyx131)
# 312               ✔️ PR #89 [G2M ] States/ezpz (hyx131)
# 313   ✔️ PR #2 Add work sample solution 1-3 (woozyking)
# 314   ✔️ PR #652 perf - geo cohort filtered query (e...
# 315   ✔️ PR #651 Customer/GeoCohort - Add cohort siz...
# 316   ✔️ PR #650 insights - geo cohort - add list na...
# 317   ✔️ PR #649 WL - endpoint to create white label...
# 318                ✔️ PR #1820 Temp geom fix (geoerika)
# 319   ✔️ PR #1819 deps - update yarn.lock to fix par...
# 320   ✔️ PR #1817 manage - fix geo cohort style (eq-...
# 321   ✔️ PR #1814 Campaign/GeoCohort - Manage cohort...
# 322   👀 PR #1813 whitelabels - add new white label c...
# 323            👀 PR #1808 geo cohort/reports (DoParkEQ)
# 324                 ✔️ PR #1812 GeoCohortMap (geoerika)
# 325            ✔️ PR #1810 OLD GeoCohort Map (geoerika)
# 326            ✔️ PR #848 geo cohort pacing (eq-ianecc)
# 327   ✔️ PR #527 QL/Logs - Allow access to global co...
# 328   ✔️ PR #24 Devops - update notebook image to v0...
# 329   ✔️ PR #23 single user server - fix poststart h...
# 330   👀 PR #80 Devops - add automated testing for de...
# 331                              ✔️ PR #78 get_audience
# 332   ✔️ PR #79 Geocode - fix missing postalcodes du...
# 333   ✔️ PR #1 recipe - search available POI lists b...
# 334   ✔️ PR #46 connection-hub - datetime serializat...
# 335   ✔️ PR #45 connectionHub - datetime serializati...
# 336   ✔️ PR #44 Revert "[G2M] connectionHub - dateti...
# 337   ✔️ PR #42 connectionHub - datetime serializati...
# 338   ✔️ PR #43 Get_polygon - include centroid to us...
# 339   ✔️ PR #950 hub/google - associate to new servi...
# 340   ⚠️ PR #947 builder - geo_cohort step support f...
# 341                                                text
# 342                     ✔️ #45 Columns/reorder (hyx131)
# 343        ⚠️ #44 re-layout (tlowande)#42 update layout
# 344   ✔️ #36 views - fix viewIndex error on view-col...
# 345                 ⚠️ #5 02 - control flow (woozyking)
# 346   ✔️ #4 01 - dissect 2/2, revise problem 03 (woo...
# 347                ✔️ #1 part 00 background (woozyking)
# 348   ✔️ #4 Writer - Process all inserts in single t...
# 349   ✔️ #3 Added Slack logger + Split cache cleanup...
# 350                           ✔️ #4 Wordwrap (tlowande)
# 351   ✔️ #42 POIMap - adjust to resizable map contai...
# 352   ⚠️ #41 ColumnPOI - adjust POIManage to latest ...
# 353                ✔️ #40 Reset/exit buttons (geoerika)
# 354   👀 #479 Add lambda authorizer + fix ML customer...
# 355   ✔️ #478 DevOps/Fix - Abstract portunus token (...
# 356   ✔️ #477 DevOps/Stages - Introduce stage stable...
# 357   ✔️ #476 ML/Logs - Add all atom insights + more...
# 358          👀 #908 - new marketplace update (DoParkEQ)
# 359   👀 #907 Add Map back under Analytics in nav (Yi...
# 360   ✔️ #14 devops -  update notebook image (bsandi...
# 361   ✔️ #13 devops -  update notebook image (bsandi...
# 362   ✔️ #41 enrich - add support for direct mapping...
# 363   ✔️ #16 Demographic/add direct mapping (bsandi1...
# 364                        👀 #7 User scope (dilanSuraj)
# 365   ✔️ #4 demo - update with aoi and demo (bsandi1...
# 366   👀 #7 Distinguish issues from PRs and better da...
# 367   ✔️ #6 daily - fix uncertain properties from is...
# 368              ✔️ #5 Digest/group by team (woozyking)
# 369                     ✔️ #4 Daily updates (woozyking)
# 370                      👀 #58 /demo command (tlowande)
# 371   ✔️ #57 Release - show prompt in channel when r...
# 372                      👀 #56 Diff/calendar (tlowande)
# 373   ✔️ #55 diff - better control, info, and highli...
# 374   ✔️ #30 tag - fix directory access to json (tlo...
# 375   👀 #843 agent - fix no expire daily nobids coun...
# 376        ✔️ #1 add header support for auth (2qU24Tlb)
# 377                                                text
# 378   👀 PR #2 Stripe - Endpoints for the core resour...
# 379                   ✔️ PR #1 lint fix (wwwmonsterlam)
# 380   👀 PR #76 cli - add locus get command for LOCUS...
# 381   ✔️ PR #69 Dataset - modify ML routes in gettin...
# 382   ✔️ PR #75 Improve getting report based on repo...
# 383   ✔️ PR #74 devops - deps, README, and top-level...
# 384   ✔️ PR #73 dataset/extra - get time zone geomet...
# 385   ✔️ PR #70 Use export endpoints when getting LO...
# 386   ✔️ PR #39 report - improve performance (bsandi...
# 387               ✔️ PR #36 Quick Query util (maluhoss)
# 388   ✔️ PR #38 Report - create new handler to get L...
# 389          ⚠️ PR #17 09 - set operations (bsandi1220)
# 390   ✔️ PR #17 daily and weekly/long-range format r...
# 391   ✔️ PR #20 journal - de-duplicate overlapping t...
# 392   ✔️ PR #646 devops - remove incorrect counter d...
# 393   ✔️ PR #642 docs - add tunnel instruction for d...
# 394   ✔️ PR #641 devops - add containerization with ...
# 395           ✔️ PR #645 geo cohort details (eq-ianecc)
# 396             ✔️ PR #644 geo cohort lists (eq-ianecc)
# 397   ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 398        👀 PR #34 New bounding box logic (tris-olson)
# 399   ✔️ PR #8 schema - update schema for empty audi...
# 400                                                text
# 401   ✔️ PR #11 04 - intro on data aggregation and v...
# 402               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 403    👀 PR #59 Access ATOM impressions logs (maluhoss)
# 404   ✔️ PR #58 geocode - append geocode result to o...
# 405   ✔️ PR #6 demo files - update to pandas df nati...
# 406   ✔️ PR #18 devops - update notebook image inclu...
# 407   👀 PR #13 Google analytics 4 connector (supunte...
# 408               👀 PR #11 Supun tests (supuntennakoon)
# 409   ✔️ PR #16 show contributors by project and gro...
# 410   ✔️ PR #36 lib - parseRaw for NLP labeling of a...
# 411          👀 PR #35 Bert embedding (steven-mindswire)
# 412    ⚠️ PR #32 nlp/label - 2021-Feb batch (woozyking)
# 413   ⚠️ PR #2 GitHub workflows setup; refactor file...
# 414     👀 PR #6 Daily pipeline/add commute (bsandi1220)
# 415   ⚠️ PR #10 ip/eval meta and ip unary clustering...
# 416   👀 PR #30 update master branch with in-producti...
# 417                                                text
# 418                      👀 #58 /demo command (tlowande)
# 419   ✔️ #57 Release - show prompt in channel when r...
# 420                      👀 #56 Diff/calendar (tlowande)
# 421   ✔️ #55 diff - better control, info, and highli...
# 422   ✔️ #30 tag - fix directory access to json (tlo...
# 423   ✔️ #29 tag - improve commit matching logic (tl...
# 424   ✔️ #6 daily - fix uncertain properties from is...
# 425              ✔️ #5 Digest/group by team (woozyking)
# 426                     ✔️ #4 Daily updates (woozyking)
# 427   ✔️ #14 devops -  update notebook image (bsandi...
# 428   ✔️ #13 devops -  update notebook image (bsandi...
# 429   ✔️ #41 enrich - add support for direct mapping...
# 430   ✔️ #40 Use get_dataset when fetching EQ datase...
# 431        ✔️ #39 Feature/popular times v2 (bsandi1220)
# 432                 ✔️ #24 Fix report method (maluhoss)
# 433   ✔️ #16 Demographic/add direct mapping (bsandi1...
# 434                        👀 #7 User scope (dilanSuraj)
# 435   ✔️ #4 demo - update with aoi and demo (bsandi1...
# 436                 ⚠️ #5 02 - control flow (woozyking)
# 437   ✔️ #4 01 - dissect 2/2, revise problem 03 (woo...
# 438                ✔️ #1 part 00 background (woozyking)
# 439   ✔️ #4 Writer - Process all inserts in single t...
# 440   ✔️ #3 Added Slack logger + Split cache cleanup...
# 441      👀 #28 Shortest path phase2 boxgen (tris-olson)
# 442     ✔️ #27 Shortest path phase2 boxgen (tris-olson)
# 443     ✔️ #26 Shortest path phase2 boxgen (tris-olson)
# 444     ✔️ #25 Shortest path phase2 boxgen (tris-olson)
# 445   ✔️ #23 Shortest path phase2 iterative starting...
# 446       👀 #2 Airflow/clustering pipeline (bsandi1220)
# 447                                                text
# 448              ✔️ PR #46 Columns/target drop (hyx131)
# 449   ✔️ PR #44 re-layout (tlowande)Issue #42 update...
# 450                           ✔️ PR #33 Tabs (tlowande)
# 451   ✔️ PR #5 devops - broaden alpha tag scopes (wo...
# 452   ✔️ PR #45 Fix github workflow token for npm pu...
# 453   ✔️ PR #44 Devops - add scope to publish and ch...
# 454   ✔️ PR #43 Storybook - include mapbox-gl.css; f...
# 455              ⚠️ PR #5 02 - control flow (woozyking)
# 456   ⚠️ PR #41 ColumnPOI - adjust POIManage to late...
# 457                  👀 PR #61 Patch calendar (tlowande)
# 458   ✔️ PR #60 devops - add googleapis secret to se...
# 459                  ✔️ PR #58 /demo command (tlowande)
# 460                  ✔️ PR #56 Diff/calendar (tlowande)
# 461   ✔️ PR #8 Catch me if you can - refactor, fix l...
# 462   ✔️ PR #7 Distinguish issues from PRs and bette...
# 463   ⚠️ PR #17 Demographic enrichment by distance (...
# 464   ✔️ PR #479 Add lambda authorizer + fix ML cust...
# 465       👀 PR #908 - new marketplace update (DoParkEQ)
# 466   ✔️ PR #882 hide marketplace from top nav (DoPa...
# 467                     👀 PR #7 User scope (dilanSuraj)
# 468   ✔️ PR #53 Confirmed Cases - fetch province fre...
# 469                                                text
# 470   👀 #36 views - fix viewIndex error on view-colu...
# 471   ✔️ #35 views - fix aggregate columns delete un...
# 472              ✔️ #34 Query/where conditions (hyx131)
# 473                              ⚠️ #33 Tabs (tlowande)
# 474                               ✔️ #32 Login (hyx131)
# 475                       ✔️ #31 View states (tlowande)
# 476    ✔️ #13 login - ml-ui gh-pages url match (hyx131)
# 477   ✔️ #12 login/ml-ui - fix product param for ml-...
# 478          ✔️ #11 Login/optional cross login (hyx131)
# 479   ✔️ #8 storage - add common storage initiation ...
# 480                 👀 #40 Reset/exit buttons (geoerika)
# 481   ✔️ #32 POICard - transition to react-labs / ma...
# 482   👀 #143 Bump ini from 1.3.5 to 1.3.8 (dependabo...
# 483                ⚠️ #4 01 - dissected 2/2 (woozyking)
# 484   ✔️ #3 01 - dissect out part 1/2 based on 1-hr ...
# 485   ✔️ #2 part 00 - background and part 01 - immed...
# 486                ✔️ #1 part 00 background (woozyking)
# 487   👀 #3 Added Slack logger + Split cache cleanup ...
# 488   ✔️ #41 POIMap - set style to layers, pitch & b...
# 489   ✔️ #3 stories - experiment and add json cell v...
# 490   👀 #13 devops -  update notebook image (bsandi1...
# 491   ✔️ #906 common-login - version upgrade with ml...
# 492   👀 #905 Bump ini from 1.3.5 to 1.3.7 (dependabo...
# 493   ✔️ #904 common-login - upgrade to version 0.8....
# 494   ✔️ #902 Failed load customer at home fixed (Do...
# 495        ✔️ #894 Navbar alternative layout (DoParkEQ)
# 496   ✔️ #884 Marketplace/knowmore (YizhiCatherineZh...
# 497   👀 #22 Bump ini from 1.3.5 to 1.3.8 (dependabot...
# 498   ✔️ #40 Use get_dataset when fetching EQ datase...
# 499        ✔️ #39 Feature/popular times v2 (bsandi1220)
# 500   ✔️ #38 fix presigned URL structure for AOI & g...
# 501   ✔️ #35 Send only geo IDs from dataset provided...
# 502                 ✔️ #24 Fix report method (maluhoss)
# 503   ✔️ #475 ML/Logs - Fast views (incl. camphistor...
# 504   👀 #474 Bump ini from 1.3.5 to 1.3.7 (dependabo...
# 505   ✔️ #473 Dataset/aoi - tweak empty data structu...
# 506   ✔️ #472 Notebook - add popular-times-v2 route ...
# 507                        ✔️ #471 Reports/aoi (hyx131)
# 508           ✔️ #15 AOI - Fix URL structure (maluhoss)
# 509   ✔️ #14 Enrich - improve error handling for ind...
# 510   ✔️ #12 Use Async for demographic enrichment (m...
# 511                        👀 #7 User scope (dilanSuraj)
# 512                        👀 #2 User scope (dilanSuraj)
# 513   👀 #4 demo - update with aoi and demo (bsandi1220)
# 514   ✔️ #1795 common-login - version upgrade with m...
# 515   ✔️ #1794 devops - add google analytics trackin...
# 516   ✔️ #1793 common-login - upgrade to version 0.8...
# 517   👀 #843 agent - fix no expire daily nobids coun...
# 518   ✔️ #842 upgrade agent deploy to am linux 2 (eq...
# 519                      👀 #4 Daily updates (woozyking)
# 520         ✔️ #3 Digest - PR linked issues (woozyking)
# 521   ✔️ #2 digest - group by categories using 'meta...
# 522   ✔️ #29 tag - improve commit matching logic (tl...
# 523   👀 #54 Bump ini from 1.3.5 to 1.3.7 (dependabot...
# 524   👀 #19 Bump ini from 1.3.5 to 1.3.8 (dependabot...
# 525   👀 #16 Bump ini from 1.3.5 to 1.3.7 (dependabot...
# 526   ✔️ #21 Popular time v2/poi reference (bsandi1220)
# 527            ✔️ #20 Fix/popular times v2 (bsandi1220)
# 528        ✔️ #19 Feature/popular times v2 (bsandi1220)
# 529   👀 #67 Bump ini from 1.3.5 to 1.3.7 (dependabot...
# 530       👀 #2 Airflow/clustering pipeline (bsandi1220)
# 531   ✔️ #27 Bump node-fetch from 2.6.0 to 2.6.1 (de...
# 532   ✔️ #24 Bump lodash from 4.17.15 to 4.17.20 (de...
# 533                                                text
# 534                   ✔️ PR #62 Test release (tlowande)
# 535       ✔️ PR #61 Widgets playground setup (tlowande)
# 536   ✔️ PR #56 Nebula update; layers error fix (geo...
# 537   ⚠️ PR #9 03 - 3/3 classes, dataframes (woozyking)
# 538   ✔️ PR #8 03 dict, set, while loop, loop contro...
# 539   👀 PR #9 Enable table heads to take a fixed amo...
# 540        👀 PR #2 API endpoints meta table (woozyking)
# 541      ✔️ PR #1 daily finance aggregation (woozyking)
# 542   ✔️ PR #50 React maps update to v.0.4.5 (geoerika)
# 543   ✔️ PR #930 Home - default wl on url and update...
# 544   👀 PR #928 Finance - smaug daily API consumptio...
# 545   ✔️ PR #927 Patch missing customers for client ...
# 546   ✔️ PR #926 Cleanup segments and widgets - use ...
# 547   ✔️ PR #925 cleanup/maps - read wl/cu from matc...
# 548   ✔️ PR #924 Cleanup - remove old nav & marketpl...
# 549   ✔️ PR #923 toastify - replace react-toastify w...
# 550   ✔️ PR #922 Cleanup/selector state - read wl/cu...
# 551   ✔️ PR #921 ml - test pre-release in maps (tlow...
# 552   ✔️ PR #920 Home/fix customer view (YizhiCather...
# 553   ✔️ PR #914 hub - new google sheets flow (woozy...
# 554              👀 PR #27 Add geocoding util (maluhoss)
# 555       ✔️ PR #26 Feature/segment create (bsandi1220)
# 556   👀 PR #493 expense - smaug daily report split b...
# 557   ✔️ PR #492 dataset routes - update smaug count...
# 558   ✔️ PR #491 smaug daily API consumption report ...
# 559   ✔️ PR #490 dataset - add routes for  presigned...
# 560   ✔️ PR #489 hub - google sheet connector (eq-ia...
# 561                   ⚠️ PR #5 widget editor (DoParkEQ)
# 562   ✔️ PR #4 dashboard & widget base structure (Do...
# 563               ✔️ PR #12 Supun tests (wwwmonsterlam)
# 564               👀 PR #11 Supun tests (supuntennakoon)
# 565      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 566   👀 PR #52 create_segment - add method to proces...
# 567             ⚠️ PR #51 Add Geocoding Util (maluhoss)
# 568   ⚠️ PR #32 nlp/label - add fixed label training...
# 569   ✔️ PR #18 journal - idle check handler and rem...
# 570   ✔️ PR #1804 hide cost column be default in rep...
# 571                 ⚠️ PR #1803 LocusPOI fix (geoerika)
# 572   ✔️ PR #1796 Integrate new poi-manage; replace ...
# 573   ✔️ PR #640 manage - mb partial updates patch w...
# 574                                                text
# 575   ⚠️ PR #23 Work with generated/fake data (woozy...
# 576   ✔️ PR #22 devops - integrate commit-watch for ...
# 577   ⚠️ PR #76 Map/GeoCohortMap  - add setZoom, set...
# 578                👀 PR #75 Intelligence map (kc-leung)
# 579          ✔️ PR #97 Executions/cancellation (hyx131)
# 580   ✔️ PR #96 devops - integrate commit-watch to m...
# 581                  ✔️ PR #95 Categories/tree (hyx131)
# 582             ✔️ PR #94 Categories/re layout (hyx131)
# 583                 ⚠️ PR #85 Add map widget (geoerika)
# 584                   ✔️ PR #164 Selector/tree (hyx131)
# 585   👀 PR #27 Commit watch integration and mention ...
# 586   ✔️ PR #59 devops - add commit-watch to master ...
# 587   ✔️ PR #58 login - send OTP email to registered...
# 588   ⚠️ PR #1833 Report/GeoCohort - use bbox coords...
# 589   ✔️ PR #1832 Manage -fix tab order at flight an...
# 590   ✔️ PR #1831 GeoCohort - Suppress error for geo...
# 591             👀 PR #1829 table enhancement (DoParkEQ)
# 592           ✔️ PR #1827 apply global theme (DoParkEQ)
# 593   ✔️ PR #1823 devops - upgrade build runtime and...
# 594           ✔️ PR #1830 Package, table fix (geoerika)
# 595   ✔️ PR #1828 Theme - fix default theme (woozyking)
# 596           ✔️ PR #1808 geo cohort/reports (DoParkEQ)
# 597   ✔️ PR #656 devops - add commit-watch to master...
# 598   👀 PR #23 journal - setup Notion dev-journal au...
# 599   ✔️ PR #42 version 3.4, revise commit-watch job...
# 600   ✔️ PR #40 devops - dev env to node 14, add com...
# 601    ✔️ PR #37 nlp/label - 2021-Mar batch (woozyking)
# 602   ✔️ PR #3 Auto main|master branch detection (wo...
# 603   👀 PR #12 Stripe - Added The extra parameteres ...
# 604   👀 PR #11 Stripe - Added The extra parameteres ...
# 605   👀 PR #9 Stripe - Endpoints for the Orders sect...
# 606   👀 PR #8 Stripe - Endpoints for the Terminal se...
# 607   👀 PR #7 Stripe - Endpoints for the Issuing sec...
# 608   👀 PR #6 Stripe - Endpoints for the Fraud secti...
# 609   👀 PR #4 Stripe - Endpoints for the Billing (su...
# 610   👀 PR #10 Stripe - Endpoints for the Sigma, Rep...
# 611   👀 PR #5 Stripe - Endpoints for the Connect (su...
# 612   ✔️ PR #16 update airflow dag deployment (wwwmo...
# 613   👀 PR #25 Devops - update image for singleuser ...
# 614   ✔️ PR #84 Devops - fix path to demo-notebooks ...
# 615   ✔️ PR #83 Devops - fix path to demo-notebooks ...
# 616   ✔️ PR #82 Add ipyleaflet, timezonefinder, modi...
# 617   ✔️ PR #80 Devops - add automated testing for d...
# 618   ✔️ PR #534 Serverless/Env - Expose STAGE var (...
# 619   ✔️ PR #533 QL/Executions - Add API triggered c...
# 620   ✔️ PR #532 Devops - commit watch integration (...
# 621   ✔️ PR #957 devops - add commit-watch to master...
# 622   ✔️ PR #919 design - change illustrations in ho...
# 623   ✔️ PR #3 Execution - Add support for cancellat...
# 624   ✔️ PR #12 Bugfix/exception detection (wwwmonst...
# 625   👀 PR #11 Shopify - Endpoints for Online Store ...
# 626   ✔️ PR #5 Added endpoints for Sales channel, Ma...
# 627   ✔️ PR #4 Shopify - Endpoints for the Events Se...
# 628   ✔️ PR #3 Shopify - Endpoints for the Inventory...
# 629   ✔️ PR #2 Shopify - Endpoints for the Orders se...
# 630   ✔️ PR #1 Shopify - Endpoints for the Products ...
# 631   ✔️ PR #10 Shopify - Endpoints for TenderTransa...
# 632   ✔️ PR #9 Shopify - Endpoints for Discounts sec...
# 633   ✔️ PR #8 Shopify - Endpoints for shopify payme...
# 634   ✔️ PR #7 Shopify - Endpoints for Store Propert...
# 635   👀 PR #6 Shopify - Endpoints for Shipping and f...
# 636   ✔️ PR #1 aws lambda - add AWS SAM based templa...
# 637                                                text
# 638   ⚠️ PR #1 Port - tensorflow playground ts (wooz...
# 639   👀 PR #5 Handle individual log views + Support ...
# 640     ✔️ PR #16 08 - workspace automation (woozyking)
# 641   ⚠️ PR #66 dokerfile - define steps for dockerf...
# 642   ✔️ PR #65 AOI - Use aoi export endpoint instea...
# 643   ⚠️ PR #33 popular times -  update decryption m...
# 644   ✔️ PR #32 AOI - refactor endpoint from /layer ...
# 645   ⚠️ PR #24 encryption - update encrypt method t...
# 646   👀 PR #137 Training Gym - Enrichment ETL (wenti...
# 647   👀 PR #135 add airflow dag file for hhv2 weekly...
# 648   👀 PR #11 Shopify - Endpoints for Online Store ...
# 649   ✔️ PR #13 Google analytics 4 connector (supunt...
# 650   ✔️ PR #1 companion project for python-curricul...
# 651   ✔️ PR #24 devops - update image from conda to ...
# 652   ✔️ PR #3 Adding auto risk score to HH Segments...
# 653    ⚠️ PR #37 nlp/label - 2021-Mar batch (woozyking)
# 654               👀 PR #183 feature/hhv2 (QingleiZhang)
# 655                                                text
# 656           ⚠️ PR #24 13 - Data processing (maluhoss)
# 657   ✔️ PR #23 Work with generated/fake data (woozy...
# 658   👀 PR #27 Commit watch integration and mention ...
# 659   ✔️ PR #19 github_action - add commit-watch (ww...
# 660      ✔️ PR #15 New table/oauth info (wwwmonsterlam)
# 661          ✔️ PR #18 fix - deployment (wwwmonsterlam)
# 662   ✔️ PR #17 fix/lambda - direct type detection. ...
# 663   ✔️ PR #86 Devops - change ray version from 1.1...
# 664   👀 PR #85 Save Dataset as Hub Connection - chec...
# 665               ✔️ PR #14 Fix/orders2 (wwwmonsterlam)
# 666                ✔️ PR #13 Fix/orders (wwwmonsterlam)
# 667   ✔️ PR #10 Shopify - Endpoints for TenderTransa...
# 668   ✔️ PR #9 Shopify - Endpoints for Discounts sec...
# 669   ✔️ PR #7 Shopify - Endpoints for Store Propert...
# 670   ✔️ PR #6 Shopify - Endpoints for Shipping and ...
# 671   ✔️ PR #11 Shopify - Endpoints for Online Store...
# 672   👀 PR #12 Stripe - Added The extra parameteres ...
# 673   👀 PR #11 Stripe - Added The extra parameteres ...
# 674   👀 PR #9 Stripe - Endpoints for the Orders sect...
# 675   👀 PR #8 Stripe - Endpoints for the Terminal se...
# 676   👀 PR #7 Stripe - Endpoints for the Issuing sec...
# 677   👀 PR #6 Stripe - Endpoints for the Fraud secti...
# 678   👀 PR #4 Stripe - Endpoints for the Billing (su...
# 679   👀 PR #10 Stripe - Endpoints for the Sigma, Rep...
# 680   👀 PR #5 Stripe - Endpoints for the Connect (su...
# 681   👀 PR #25 Devops - update image for singleuser ...
# 682   ✔️ PR #53 Athena/BeaconConv - Fix - SQL dict t...
# 683   ✔️ PR #37 updated div_distance to increase div...
# 684   ✔️ PR #23 journal - setup Notion dev-journal a...
# 685                👀 PR #1 Revised deployment (odesiuz)
# 686          👀 PR #2 Cohort matrix creation (safayet08)
# 687            👀 PR #4 losses visualization (woozyking)
# 688               ⚠️ PR #3 ip hh dev (steven-mindswire)
# 689   ✔️ PR #1 aws lambda - add AWS SAM based templa...
# 690   ✔️ PR #3 extract data of place of worship from...
# 691                                                text
# 692            👀 PR #5 Hivestack index filter (odesiuz)
# 693                👀 PR #3 Commute direction (dshparyk)
# 694   ✔️ PR #134 Merge airflow_reoccuring_jobs branc...
# 695   ✔️ PR #133 create_dag - add popular times segm...
# 696               ✔️ PR #12 Supun tests (wwwmonsterlam)
# 697               👀 PR #11 Supun tests (supuntennakoon)
# 698      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 699   👀 PR #52 create_segment - add method to proces...
# 700             ⚠️ PR #51 Add Geocoding Util (maluhoss)
# 701        👀 PR #26 Feature/segment create (bsandi1220)
# 702   ✔️ PR #18 journal - idle check handler and rem...
# 703   ✔️ PR #6 REPLACER - add popular times datasour...
# 704   ✔️ PR #640 manage - mb partial updates patch w...
# 705   ✔️ PR #8 03 dict, set, while loop, loop contro...
# 706      ✔️ PR #1 daily finance aggregation (woozyking)
# 707   ✔️ PR #21 Popular times v2/dynamodb upload (bs...
# 708   👀 PR #28 Shortest path phase2 boxgen (tris-olson)
# 709                                                text
# 710   ⚠️ PR #55 Age Chart for Ontario (maluhoss)Issu...
# 711        👀 PR #2 Ip classification (steven-mindswire)
# 712   ✔️ PR #14 Backwards compatibility/service acco...
# 713       ✔️ PR #13 Connector/framework (wwwmonsterlam)
# 714   ⚠️ PR #8 gam - multi-read, multi-write process...
# 715   👀 PR #42 connectionHub - datetime serializatio...
# 716   👀 PR #23 single user server - fix poststart ho...
# 717                               👀 PR #78 get_audience
# 718   👀 PR #135 add airflow dag file for hhv2 weekly...
# 719   ⚠️ PR #2 Add work sample solution 1-3 (woozyking)
# 720             👀 PR #126 VISX/Plotly/D3 exp (DoParkEQ)
# 721            ✔️ PR #648 geo cohort pacing (eq-ianecc)
# 722       ✔️ PR #34 New bounding box logic (tris-olson)
# 723                ✔️ PR #1 Step fn migration (odesiuz)
# 724   ⚠️ PR #1 Port - tensorflow playground ts (wooz...
# 725                                                text
# 726   ✔️ PR #122 data - add Pandas variant, revise i...
# 727   ✔️ PR #113 product - re-org tracks and revise ...
# 728   ✔️ PR #2 docker - use jupyter/pyspark-notebook...
# 729   👀 PR #11 Shopify - Endpoints for Online Store ...
# 730   👀 PR #5 Added endpoints for Sales channel, Mar...
# 731   👀 PR #2 Shopify - Endpoints for the Orders sec...
# 732   👀 PR #10 Shopify - Endpoints for TenderTransac...
# 733   👀 PR #9 Shopify - Endpoints for Discounts sect...
# 734   👀 PR #8 Shopify - Endpoints for shopify paymen...
# 735   👀 PR #7 Shopify - Endpoints for Store Properti...
# 736   👀 PR #6 Shopify - Endpoints for Shipping and f...
# 737   ✔️ PR #8 demo aoi - update with improve  get_g...
# 738   ✔️ PR #64 get_audience_from_poi_list - align c...
# 739    ✔️ PR #63 AOI - Improve fetching data (maluhoss)
# 740      ✔️ PR #31 AOI - improve scalability (maluhoss)
# 741   ✔️ PR #23 popular-times-v1 - remove API backen...
# 742   👀 PR #13 Google analytics 4 connector (supunte...
# 743   ✔️ PR #15 07 - interactive visualization (bsan...
# 744   ✔️ PR #23 Airflow pipeline/fix tasks dates (bs...
# 745   ✔️ PR #22 popular times v1 - remove preprocess...
# 746    👀 PR #1 restructure and amend doc (QingleiZhang)
# 747   ⚠️ PR #1 Port - tensorflow playground ts (wooz...
# 748      👀 PR #12 Bell test final filter (QingleiZhang)
# 749    👀 PR #11 Bell test data clean (steven-mindswire)
# 750   ✔️ PR #33 small updates to readmes & comments ...
# 751   👀 PR #30 update master branch with in-producti...
# 752   ✔️ PR #8 Remove flaged audience (steven-mindsw...
# 753   ✔️ PR #7 replace deprecated use_batch_mode wit...
# 754                👀 PR #3 Commute direction (dshparyk)
# 755   👀 PR #179 change centroid label algorithm (Qin...
# 756                                                text
# 757   ⚠️ PR #17 fix overlapped table borders (kc-leu...
# 758      ⚠️ PR #69 ML Report Map -add legend (geoerika)
# 759                ⚠️ PR #68 heatmap example (DoParkEQ)
# 760   ✔️ PR #67 MlReportMap - add/fix configurations...
# 761   ✔️ PR #66 Adjust code to work with poi-manage ...
# 762   ✔️ PR #7 Add color variants to button (kc-leun...
# 763                         ✔️ PR #158 Modal (DoParkEQ)
# 764               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 765   👀 PR #74 devops - deps, README, and top-level ...
# 766   ✔️ PR #68 get_dataset - update get connection ...
# 767   ⚠️ PR #73 dataset/extra - get time zone geomet...
# 768      ✔️ PR #72 devops - fix dockerfile (bsandi1220)
# 769   👀 PR #70 Use export endpoints when getting LOC...
# 770   ✔️ PR #71 AOI - add version when saving file (...
# 771   👀 PR #69 Dataset - modify ML routes in getting...
# 772   ✔️ PR #67 get_audience - add limit to number o...
# 773   👀 PR #946 hub - new s3 connector based direct ...
# 774   ⚠️ PR #939 ml - upgrade ml version + react-que...
# 775   👀 PR #919 design - change illustrations in hom...
# 776   ✔️ PR #514 docs - deployment slash command (wo...
# 777      ✔️ PR #512 devops - docker compose (woozyking)
# 778   👀 PR #505 ML Overhaul - Executions + saved que...
# 779   👀 PR #513 Dataset - create new endpoint to get...
# 780   ⚠️ PR #511 Create quick query endpoint for not...
# 781   ✔️ PR #510 Modify report export endpoints to i...
# 782   ✔️ PR #509 Report - List reports based on acce...
# 783   ✔️ PR #508 dataset - add route to get connecti...
# 784   ⚠️ PR #38 Report - create new handler to get L...
# 785   ✔️ PR #35 connectionHub - add get connection m...
# 786   ✔️ PR #37 AOI - use geo_id instead of resoluti...
# 787               ⚠️ PR #36 Quick Query util (maluhoss)
# 788   ✔️ PR #9 AOI file - adjust column names when g...
# 789   ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 790   👀 PR #642 docs - add tunnel instruction for do...
# 791   ✔️ PR #641 devops - add containerization with ...
# 792   ✔️ PR #51 Bids History - Support for geo cohor...
# 793   ✔️ PR #50 Features Writer - Add support for mu...
# 794            👀 PR #846 feature/geo-cohort (eq-ianecc)
# 795   ✔️ PR #845 adserver - support new AUDIT macro ...
# 796               👀 PR #7 geo cohort fields (eq-ianecc)
# 797                                                text
# 798   ✔️ PR #47 devops - auto documentation generate...
# 799   ✔️ PR #46 Fix missing reports when retrieving ...
# 800   ✔️ PR #45 Send readable error if wrong report ...
# 801            ✔️ PR #44 Access hub datasets (maluhoss)
# 802      👀 PR #9 Google analytics supun (wwwmonsterlam)
# 803   👀 PR #19 Update - Add device capture and expor...
# 804   ✔️ PR #18 Update - Add SDR to data sources (mp...
# 805   ⚠️ PR #10 ip/eval meta and ip unary clustering...
# 806   ⚠️ PR #7 03 - data containers and repetitions ...
# 807   ✔️ PR #6 02 - logic controls (try/except, asse...
# 808   ✔️ PR #26 meetings - guideline with link to /n...
# 809   ✔️ PR #25 Dev journal - update with asana auto...
# 810   ✔️ PR #24 update documentation with bday, demo...
# 811   ✔️ PR #23 meetings - update with recent progre...
# ...
# 1157   Fix test errors by rolling back react/maps; u...
# 1158                           Update package to v1.0.0
# 1159     Upgrade workflow actions and react-map package
# 1160          Add mapboxApiAccessToken ; refactor props
# 1161   ColumnPOI - adjust POIManage to latest versio...
# 1162                  experiment on visx/d3 integration
# 1163                          devops - add auto-release
# 1164          tabs - add forwardRef to use with drawers
# 1165               03 - data containers and repetitions
# 1166   02 - logic controls (try/except, assert, extr...
# 1167   devops/npm-publish - enforce public access of...
# 1168                add storybook and remove inline css
# 1169            tag - make access to package.json safer
# 1170                 journal - remove optional chaining
# 1171   Journal/vacay - skip journal process during v...
# 1172   github - lone repo updates to factor in teams...
# 1173   offWeekDaysDurations and support unavailable ...
# 1174                     Bday sign fix multi-bday logic
# 1175       Update - Add device capture and export to S3
# 1176                   Update - Add SDR to data sources
# 1177                           Integrate new poi-manage
# 1178                                       text_cleaned
# 1179   add Quantitave & Qualitative filter (kc-leung...
# 1180                                        States/ezpz
# 1181                                               Ezpz
# 1182                   State Management with Easy-Peasy
# 1183                                   Ongoing projects
# 1184                        package - changed to v1.1.0
# 1185                         Port styled card container
# 1186   alert - simplification - header case logic, r...
# 1187             import modal and styled card container
# 1188   add forwardRef wrapper to every component (kc...
# 1189                       Add work sample solution 1-3
# 1190   Legend scale fix for zero max; rename MLRepor...
# 1191   Geo Cohort Map - create geojson map; data-bas...
# 1192                                 VISX/Plotly/D3 exp
# 1193                                          Extracted
# 1194   alert - simplify alert and eliminate inline-s...
# 1195   Age Chart for Ontario (maluhoss)Issue Age bre...
# 1196                                       GeoCohortMap
# 1197                                  OLD GeoCohort Map
# 1198                                 geo cohort/reports
# 1199                                  geo cohort pacing
# 1200            Backwards compatibility/service account
# 1201                                Connector/framework
# 1202   gam - multi-read, multi-write process ready f...
# 1203      hub/google - associate to new service account
# 1204   design - change illustrations in home and not...
# 1205         hub - adapt to new staged data-hub lambdas
# 1206    HH Segments - expand access to include ONLIA WL
# 1207    QL/Geo - Move intersection table to locus_place
# 1208      connectionHub - datetime serialization bugfix
# 1209   single user server - fix poststart hook due t...
# 1210                                                NaN
# 1211                    Port - tensorflow playground ts
# 1212                                       text_cleaned
# 1213                  dashboard management interactions
# 1214    ML Log updates + Query executions orchestration
# 1215           ML Overhaul - Executions + saved queries
# 1216   AOI - include requests from notebook when exp...
# 1217          dataset - /tz for world timezone geometry
# 1218                         Devops - update serverless
# 1219          hub - google analytics connectors support
# 1220                hub - Google Analytics V4 connector
# 1221   hub - new connection split button for more types
# 1222                  map - adjust controllers position
# 1223      ml - upgrade ml version + react-query version
# 1224                                         ML connect
# 1225            dokerfile - define steps for dockerfile
# 1226     AOI - Use aoi export endpoint instead of layer
# 1227           popular times - update decryption method
# 1228   AOI - refactor endpoint from /layer to /expor...
# 1229   encryption - update encrypt method to achieve...
# 1230                       Google analytics 4 connector
# 1231     query builder - error handling and defaultView
# 1232    view/default-state - scroll to last opened view
# 1233                                      Saved queries
# 1234   Adjust code to work with poi-manage create po...
# 1235   POIMap - combine geocoder and drawing to crea...
# 1236   Handle individual log views + Support for dir...
# 1237                       Add color variants to button
# 1238                                    Vertical navbar
# 1239                                              Modal
# 1240   Implement create POIs with new POIMap create ...
# 1241                          08 - workspace automation
# 1242                    Port - tensorflow playground ts
# 1243    Upgrade version, add error handling & docstirng
# 1244         companion project for python-curriculum/08
# 1245                         nlp/label - 2021-Mar batch
# 1246                                       text_cleaned
# 1247   Stripe - Added The extra parameteres for the ...
# 1248   Stripe - Added The extra parameteres for the ...
# 1249          Stripe - Endpoints for the Orders section
# 1250        Stripe - Endpoints for the Terminal section
# 1251         Stripe - Endpoints for the Issuing section
# 1252           Stripe - Endpoints for the Fraud section
# 1253                 Stripe - Endpoints for the Billing
# 1254   Stripe - Endpoints for the Sigma, Reporting, ...
# 1255                 Stripe - Endpoints for the Connect
# 1256                      update airflow dag deployment
# 1257     Devops - update image for singleuser to v0.8.0
# 1258          Devops - fix path to demo-notebooks tests
# 1259          Devops - fix path to demo-notebooks tests
# 1260   Add ipyleaflet, timezonefinder, modin and ray...
# 1261   Devops - add automated testing for demo noteb...
# 1262                         Bugfix/exception detection
# 1263   Added endpoints for Sales channel, MarketingE...
# 1264         Shopify - Endpoints for the Events Section
# 1265      Shopify - Endpoints for the Inventory Section
# 1266         Shopify - Endpoints for the Orders section
# 1267       Shopify - Endpoints for the Products section
# 1268   Shopify - Endpoints for TenderTransaction, Me...
# 1269           Shopify - Endpoints for shopify payments
# 1270           Shopify - Endpoints for Store Properties
# 1271   Shopify - Endpoints for Shipping and fulfillm...
# 1272   Commit watch integration and mention in git c...
# 1273              devops - integrate commit-watch for s
# 1274               version 3.4, revise commit-watch job
# 1275   devops - dev env to node 14, add commit-watch...
# 1276                         nlp/label - 2021-Mar batch
# 1277                  Auto main|master branch detection
# 1278                                      Journey speed
# 1279    devops - add commit-watch to master CI workflow
# 1280                                 Revised deployment
# 1281                             Cohort matrix creation
# 1282                          idfa tracking - prototype
# 1283                                          ip hh dev
# 1284                                       text_cleaned
# 1285   port - tensorflow playground simulation logic...
# 1286                               New table/oauth info
# 1287                   Dataset - get Marketplace layers
# 1288   Devops - add automated testing for demo noteb...
# 1289                             Get Marketplace Layers
# 1290          Devops - update notebook image to v0.7.11
# 1291                                        10 raw html
# 1292                   10 - bridging web ui to notebook
# 1293             projects - add Geo Cohort project/team
# 1294                     GeoCohort/Fix - Export handler
# 1295                  GeoCohortAvail - Implement lambda
# 1296   GeoCohortAvail/devops - resolve npm registry ...
# 1297              Athena - Modularize + GeoCohort Codes
# 1298                                 geo cohort fsa agg
# 1299          Customer/GeoCohort - Geo avail from table
# 1300                   perf - geo cohort filtered query
# 1301                                          ip hh dev
# 1302                                       text_cleaned
# 1303                               Marketplace bugfixes
# 1304                                         ML connect
# 1305                                             Navbar
# 1306                               Marketplace/knowmore
# 1307  Vast/Logger - No log for non-vast/empty s3 obj...
# 1308  Archive: use SSM for PG env + Slack handler: a...
# 1309    DevOps/Fix - Yarn @eqworks from GitHub registry
# 1310  Logging - Add Slack to archive, vast & viewabi...
# 1311                      Master rebase v1 - second try
# 1312                                   Master v1 rebase
# 1313                                   V1 0.4.0 release
# 1314                   CustomPOIList - fix activeMarker
# 1315  CustomPOIList - update components after poi li...
# 1316                                  storybook env var
# 1317                                             Deploy
# 1318                                          Table fix
# 1319              results - fix json cell visualization
# 1320                              Views/persist columns
# 1321    view/default-state - scroll to last opened view
# 1322                                          Templates
# 1323                         Views - ease-of-use tweaks
# 1324                                         React grid
# 1325                          Feature/aoi presigned url
# 1326                   Update - Add SDR to data sources
# 1327              Handle timeout when fetching AOI data
# 1328  airflowize daily commute and commute wrapper o...
# 1329      Shortest path phase2 iterative starting point
# 1330      stories - experiment and add json cell values
# 1331                    demo - update with aoi and demo
# 1332            github - get issues/s by datetime range
# 1333    create interface for goolge analytics connector
# 1334  POIMap - add radius switch, refactor layer pro...
# 1335                                 nlp - auto retrain
# 1336                               fix release workflow
# 1337  devops - add gh action to auto release tag bas...
# 1338                    redis cache - use global client
# 1339          Notebook - add tracking to dataset routes
# 1340                v0.2.0 - Extract API and Formatting
# 1341                        Airflow/clustering pipeline
# 1342                        range filter UI improvement
# 1343                                       text_cleaned
# 1344                                       feature/hhv2
# 1345   journal - setup asana oauth flow via slack modal
# 1346   Create new note in Hugo meetings with slack d...
# 1347     common/baseHandler - filter out revert commits
# 1348                         nlp/label - 2021-Feb batch
# 1349                       Google analytics 4 connector
# 1350                                        Supun tests
# 1351                             Google analytics supun
# 1352                    Feature/native df compatibility
# 1353                    Feature/native df compatibility
# 1354                     Save dataset as hub connection
# 1355   AOI - Change routes to use query params for s...
# 1356   create_segment - add method to process audien...
# 1357                                 Add Geocoding Util
# 1358                      devops -update notebook image
# 1359   flow/utils - support lookalike segments and d...
# 1360                                       Exp autosize
# 1361   popular times - refactor segment to use datap...
# 1362                             Feature/segment create
# 1363   popular times - fix emr task definition and r...
# 1364        add airflow dag file for hhv2 weekly update
# 1365                             Hari clustering for pr
# 1366                    Clustering pipeline/add polygon
# 1367                          restructure and amend doc
# 1368              03 - 3/3 classes, pandas (dataframes)
# 1369                           API endpoints meta table
# 1370                                  Commute direction
# 1371                                       text_cleaned
# 1372                            devops - fix serverless
# 1373   encryption - update encrypt method to achieve...
# 1374                            devops - fix serverless
# 1375           popular times - update decryption method
# 1376            dokerfile - define steps for dockerfile
# 1377    Upgrade version, add error handling & docstirng
# 1378   Handle individual log views + Support for dir...
# 1379                                       text_cleaned
# 1380   02 - logic controls (bitwise operations, try/...
# 1381   02 - logic controls (conditions, boolean oper...
# 1382                                  Asana/dev journal
# 1383   devJournal - export methods for legion slack ...
# 1384                                        Dev journal
# 1385                                     Patch calendar
# 1386                 Demographic enrichment by distance
# 1387                        Airflow/clustering pipeline
# 1388                                       text_cleaned
# 1389       update master branch with in-production code
# 1390   Bids History - Support for geo cohorts + refa...
# 1391   Features Writer - Add support for multi dimen...
# 1392   devops - add containerization with docker-com...
# 1393   Report - create new handler to get LOCUS repo...
# 1394          connectionHub - add get connection method
# 1395   AOI - use geo_id instead of resolution column...
# 1396                                   Quick Query util
# 1397                            devops - fix dockerfile
# 1398    Use export endpoints when getting LOCUS reports
# 1399                 AOI - add version when saving file
# 1400   Dataset - modify ML routes in getting list of...
# 1401         get_audience - add limit to number of pois
# 1402       get_dataset - update get connection hub data
# 1403   AOI file - adjust column names when getting A...
# 1404                      Training Gym - Enrichment ETL
# 1405                                  geo cohort fields
# 1406        bell test core code with statistics and doc
# 1407                                    VISX/Plotly exp
# 1408                                       text_cleaned
# 1409                                            Heatmap
# 1410              create_dag - update dag id and params
# 1411   Stripe - Endpoints for the Sigma, Reporting, ...
# 1412                 Stripe - Endpoints for the Connect
# 1413          Stripe - Endpoints for the Orders section
# 1414        Stripe - Endpoints for the Terminal section
# 1415         Stripe - Endpoints for the Issuing section
# 1416           Stripe - Endpoints for the Fraud section
# 1417                 Stripe - Endpoints for the Billing
# 1418   Stripe- Endpoints for the payment methods and...
# 1419          Stripe - Endpoints for the core resources
# 1420                   segment - import new crypt class
# 1421                            Devops - fix serverless
# 1422                                                NaN
# 1423                        docker image - update steps
# 1424   cli - add locus get command for LOCUS API req...
# 1425               devops - add dockerfile of hub image
# 1426                     devops - update notebook image
# 1427                                  geo cohort pacing
# 1428                                  geo cohort manage
# 1429         - REPLACER - added eq-commute data sources
# 1430                                09 - set operations
# 1431                                    VISX/Plotly exp
