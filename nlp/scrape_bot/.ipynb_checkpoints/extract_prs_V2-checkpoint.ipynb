# %%
import glob 
import re
import json
import pandas as pd
from bs4 import BeautifulSoup

# %%
def item_filter_2(tag):
    cond = tag.name == 'li'
    cond = cond and tag.find('a').get('href')
    cond = cond and 'pull' in cond.split('/')[-2] # look for Git pull requests
    return cond

# %%
def extract_state(row):
    symbol = [sym for sym in state_symbols if (sym in row)]
    if len(symbol) == 1:
        return state_map[symbol[0]]
    return ''

state_map = {
    '⚠': 'wip',
    '👀': 'needs review',
    '✔': 'done',
}

state_symbols = list(state_map.keys())

# %%
def extract_contributors(text):
    contributors = text.split('(')[-1].split(')')[0]
    if text == contributors:
        return ''
    return contributors

# %%
def clean_2(text):

    text = text.split(' ') # split text on spaces
    for t in text:
        # remove any state symbols
        if any (sym in t for sym in state_symbols):
            text.remove(t)
    
    del text[-1] # remove contributor 
    text = ' '.join(text) # join back into single string
    # Remove square brackets and anything inside
    pattern = r'\[.*?\]'
    text = re.sub(pattern, '', text)
    # Remove any token with '#'
    text = " ".join(filter(lambda x:x[0]!='#', text.split()))
    # Remove any 'PR'
    text = text.replace('PR', "")

    return text

# %%
def clean_file(filename):
    print(filename)
    with open(filename) as f:
        data = json.load(f)
                
    soup = BeautifulSoup(data['full'], 'html.parser')
    
    data = []
    for it in soup.find_all(item_filter_2):
        data.append({
            'text': it.text,
            'link': it.find('a').get('href'),
        })
    df = pd.DataFrame(data)
    
    df['state'] = df.text.apply(extract_state)

    df['contributors'] = df.text.apply(extract_contributors)

    df['text_cleaned'] = df.text.apply(clean_2)
    
    df.to_csv(r'./scrape_prs/{}.csv'.format(filename.split('/')[-1]), header=True, index=None, mode='w')
    
    return df

fail_c = 0
for filename in glob.glob('./scrape_raw/*.json'):
    try: 
        df = clean_file(filename)
    except:
        print('failed')
        fail_c += 1
        pass
# Out:
# ./scrape_raw/DATA Digest from Mon, Jan 04 to Sun, Jan 10, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jun 08 to Mon, Jun 14, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest from Tue, Feb 02 to Mon, Feb 8, 2021.json
# ./scrape_raw/DATA Digest - Mon, Mar 08 to Sun, Mar 14, 2021.json
# ./scrape_raw/DATA Digest from Mon, Jan 18 to Sun, Jan 24, 2021.json
# ./scrape_raw/DATA Digest - Mon, May 03 to Sun, May 9, 2021.json
# ./scrape_raw/DATA Digest - Mon, Mar 01 to Sun, Mar 7, 2021.json
# ./scrape_raw/PRODUCT Digest from Tue, Jan 05 to Mon, Jan 11, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jul 06 to Mon, Jul 12, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest from Tue, Jan 19 to Mon, Jan 25, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, May 18 to Mon, May 24, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, May 04 to Mon, May 10, 2021.json
# ./scrape_raw/DESIGN Digest - Mon, Jul 19 to Sun, Jul 25, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest from Tue, Dec 15 to Mon, Dec 21, 2020.json
# ./scrape_raw/DESIGN Digest - Mon, Jul 05 to Sun, Jul 11, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Apr 12 to Sun, Apr 18, 2021.json
# ./scrape_raw/DATA Digest - Mon, Jun 28 to Sun, Jul 4, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Feb 22 to Sun, Feb 28, 2021.json
# ./scrape_raw/DATA Digest from Mon, Dec 14 to Sun, Dec 20, 2020.json
# ./scrape_raw/PRODUCT Digest from Tue, Dec 22 to Mon, Dec 28, 2020.json
# ./scrape_raw/Dev Digest - from Tue, Dec 08 to Mon, Dec 14, 2020.json
# ./scrape_raw/DATA Digest - Mon, Feb 15 to Sun, Feb 21, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest from Tue, Jan 26 to Mon, Feb 1, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jun 22 to Mon, Jun 28, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, May 25 to Mon, May 31, 2021.json
# ./scrape_raw/DATA Digest - Mon, Mar 22 to Sun, Mar 28, 2021.json
# ./scrape_raw/DATA Digest - Mon, May 31 to Sun, Jun 6, 2021.json
# ./scrape_raw/DATA Digest from Mon, Jan 25 to Sun, Jan 31, 2021.json
# ./scrape_raw/DATA Digest - Mon, Apr 26 to Sun, May 2, 2021.json
# ./scrape_raw/DATA Digest - Mon, Jul 12 to Sun, Jul 18, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Mar 15 to Sun, Mar 21, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jun 15 to Mon, Jun 21, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Jun 01 to Mon, Jun 7, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Apr 06 to Mon, Apr 12, 2021.json
# ./scrape_raw/DATA Digest from Mon, Jan 11 to Sun, Jan 17, 2021.json
# ./scrape_raw/DATA Digest - Mon, Feb 08 to Sun, Feb 14, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Jun 21 to Sun, Jun 27, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Jul 26 to Sun, Aug 1, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, May 11 to Mon, May 17, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Apr 20 to Mon, Apr 26, 2021.json
# ./scrape_raw/DATA Digest - Mon, Jun 07 to Sun, Jun 13, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Jul 05 to Sun, Jul 11, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Jul 19 to Sun, Jul 25, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Mar 30 to Mon, Apr 5, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Mar 09 to Mon, Mar 15, 2021.json
# ./scrape_raw/PRODUCT Digest from Tue, Dec 29, 2020 to Mon, Jan 4, 2021.json
# ./scrape_raw/Dev Digest - from Tue, Dec 01 to Mon, Dec 7, 2020.json
# failed
# ./scrape_raw/DATA Digest - Mon, May 17 to Sun, May 23, 2021.json
# ./scrape_raw/DATA Digest from Mon, Dec 21 to Sun, Dec 27, 2020.json
# ./scrape_raw/PRODUCT Digest - Tue, Jun 29 to Mon, Jul 5, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Mar 02 to Mon, Mar 8, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Feb 16 to Mon, Feb 22, 2021.json
# failed
# ./scrape_raw/DESIGN Digest - Mon, Jul 26 to Sun, Aug 1, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Jul 27 to Mon, Aug 2, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Apr 13 to Mon, Apr 19, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Mar 16 to Mon, Mar 22, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jul 13 to Mon, Jul 19, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest - Tue, Feb 23 to Mon, Mar 1, 2021.json
# ./scrape_raw/DATA Digest - Mon, Jun 14 to Sun, Jun 20, 2021.json
# failed
# ./scrape_raw/PRODUCT Digest from Tue, Jan 12 to Mon, Jan 18, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Apr 27 to Mon, May 3, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Mar 23 to Mon, Mar 29, 2021.json
# ./scrape_raw/DATA Digest - Mon, May 24 to Sun, May 30, 2021.json
# ./scrape_raw/DESIGN Digest - Mon, Jun 28 to Sun, Jul 4, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, May 10 to Sun, May 16, 2021.json
# ./scrape_raw/Dev Digest - from Mon, Nov 23 to Mon, Nov 30, 2020.json
# ./scrape_raw/DATA Digest from Mon, Feb 01 to Sun, Feb 7, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Jul 20 to Mon, Jul 26, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Mar 29 to Sun, Apr 4, 2021.json
# ./scrape_raw/DATA Digest from Mon, Dec 28, 2020 to Sun, Jan 3, 2021.json
# ./scrape_raw/PRODUCT Digest - Tue, Feb 09 to Mon, Feb 15, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Apr 05 to Sun, Apr 11, 2021.json
# ./scrape_raw/DESIGN Digest - Mon, Jul 12 to Sun, Jul 18, 2021.json
# failed
# ./scrape_raw/DATA Digest - Mon, Apr 19 to Sun, Apr 25, 2021.json

# %%
pd.set_option('display.max_rows', None)

fns = []
for filename in glob.glob('./scrape_prs/*.csv'): 
    fns.append(filename)
    
print('Failed to clean {} files.'.format(fail_c))
print('Cleaned {} files.'.format(len(fns)))
df = pd.read_csv(fns[20])
df
# Out:
# Failed to clean 27 files.
# Cleaned 47 files.
#                                                  text  \
# 0     ✔️ PR #655 Geocohort insights fsa agg (kevlabs)
# 1           ✔️ PR #654 geo cohort fsa agg (eq-ianecc)
# 2   ✔️ PR #653 Customer/GeoCohort - Geo avail from...
# 3   👀 PR #1823 devops - upgrade build runtime and ...
# 4   ✔️ PR #1822 More optimal Geocohort API calls t...
# 5   ✔️ PR #1821 FSA to postal codes transition for...
# 6   ✔️ PR #1813 whitelabels - add new white label ...
# 7            👀 PR #1808 geo cohort/reports (DoParkEQ)
# 8   ✔️ PR #52 GeoCohort/Fix - Export handler (kevl...
# 9   ✔️ PR #50 GeoCohortAvail - Implement lambda (k...
# 10  ✔️ PR #51 GeoCohortAvail/devops - resolve npm ...
# 11  ✔️ PR #52 Athena - Modularize + GeoCohort Code...
# 12         👀 PR #57 devops - CI revisions (woozyking)
# 13         ✔️ PR #56 jwt/long-lasting-jwt (waynezhu6)
# 14  ✔️ PR #93 devops - automate release notes upda...
# 15                   ✔️ PR #92 Columns/alias (hyx131)
# 16                 ✔️ PR #91 UI/enhancements (hyx131)
# 17                   ✔️ PR #90 Nav/execution (hyx131)
# 18                  ✔️ PR #20 10 raw html (woozyking)
# 19  ✔️ PR #19 10 - bridging web ui to notebook (di...
# 20                ⚠️ PR #73 Get zoom, bbox (geoerika)
# 21  ✔️ PR #2 projects - add Geo Cohort project/tea...
# 22  ✔️ PR #21 Incorporate lumen-ui theme (kc-leung...
# 23  👀 PR #956 ql - upgrade package with v1.1.0 rel...
# 24  ✔️ PR #955 devops - upgrade build dev deps and...
# 25     ⚠️ PR #15 New table/oauth info (wwwmonsterlam)
# 26  ✔️ PR #531 QL/Expression - Add support for col...
# 27  ✔️ PR #530 Dataset - get marketplace layers (m...
# 28  👀 PR #81 Dataset - get Marketplace layers (mal...
# 29  👀 PR #80 Devops - add automated testing for de...
# 30         👀 PR #47 Get Marketplace Layers (maluhoss)
# 31  👀 PR #1 port - tensorflow playground simulatio...
#
#                                                  link         state  \
# 0        https://github.com/EQWorks/overseer/pull/655          done
# 1        https://github.com/EQWorks/overseer/pull/654          done
# 2        https://github.com/EQWorks/overseer/pull/653          done
# 3       https://github.com/EQWorks/overlord/pull/1823  needs review
# 4       https://github.com/EQWorks/overlord/pull/1822          done
# 5       https://github.com/EQWorks/overlord/pull/1821          done
# 6       https://github.com/EQWorks/overlord/pull/1813          done
# 7       https://github.com/EQWorks/overlord/pull/1808  needs review
# 8   https://github.com/EQWorks/chronos-lambda/pull/52          done
# 9   https://github.com/EQWorks/chronos-lambda/pull/50          done
# 10  https://github.com/EQWorks/chronos-lambda/pull/51          done
# 11  https://github.com/EQWorks/camp-history-writer...          done
# 12       https://github.com/EQWorks/keywarden/pull/57  needs review
# 13       https://github.com/EQWorks/keywarden/pull/56          done
# 14           https://github.com/EQWorks/ml-ui/pull/93          done
# 15           https://github.com/EQWorks/ml-ui/pull/92          done
# 16           https://github.com/EQWorks/ml-ui/pull/91          done
# 17           https://github.com/EQWorks/ml-ui/pull/90          done
# 18  https://github.com/EQWorks/python-curriculum/p...          done
# 19  https://github.com/EQWorks/python-curriculum/p...          done
# 20      https://github.com/EQWorks/react-maps/pull/73           wip
# 21               https://github.com/EQWorks/kb/pull/2          done
# 22     https://github.com/EQWorks/lumen-table/pull/21          done
# 23          https://github.com/EQWorks/snoke/pull/956  needs review
# 24          https://github.com/EQWorks/snoke/pull/955          done
# 25        https://github.com/EQWorks/data-hub/pull/15           wip
# 26     https://github.com/EQWorks/firstorder/pull/531          done
# 27     https://github.com/EQWorks/firstorder/pull/530          done
# 28        https://github.com/EQWorks/locussdk/pull/81  needs review
# 29        https://github.com/EQWorks/locussdk/pull/80  needs review
# 30      https://github.com/EQWorks/EnrichData/pull/47  needs review
# 31           https://github.com/EQWorks/nn-viz/pull/1  needs review
#
#      contributors                                       text_cleaned
# 0         kevlabs                         Geocohort insights fsa agg
# 1       eq-ianecc                                 geo cohort fsa agg
# 2         kevlabs          Customer/GeoCohort - Geo avail from table
# 3       woozyking   devops - upgrade build runtime and clean up d...
# 4       woozyking       More optimal Geocohort API calls through SWR
# 5        geoerika             FSA to postal codes transition for map
# 6       woozyking   whitelabels - add new white label creation fe...
# 7        DoParkEQ                                 geo cohort/reports
# 8         kevlabs                     GeoCohort/Fix - Export handler
# 9         kevlabs                  GeoCohortAvail - Implement lambda
# 10      woozyking   GeoCohortAvail/devops - resolve npm registry ...
# 11        kevlabs              Athena - Modularize + GeoCohort Codes
# 12      woozyking                              devops - CI revisions
# 13      waynezhu6                               jwt/long-lasting-jwt
# 14         hyx131   devops - automate release notes updating process
# 15         hyx131                                      Columns/alias
# 16         hyx131                                    UI/enhancements
# 17         hyx131                                      Nav/execution
# 18      woozyking                                        10 raw html
# 19      divyselva                   10 - bridging web ui to notebook
# 20       geoerika                                     Get zoom, bbox
# 21      woozyking             projects - add Geo Cohort project/team
# 22       kc-leung   Incorporate lumen-ui theme (kc-leung)Issue In...
# 23         hyx131           ql - upgrade package with v1.1.0 release
# 24      woozyking   devops - upgrade build dev deps and babel config
# 25  wwwmonsterlam                               New table/oauth info
# 26        kevlabs     QL/Expression - Add support for column aliases
# 27       maluhoss                   Dataset - get marketplace layers
# 28       maluhoss                   Dataset - get Marketplace layers
# 29      waynezhu6   Devops - add automated testing for demo noteb...
# 30       maluhoss                             Get Marketplace Layers
# 31      woozyking   port - tensorflow playground simulation logic...
