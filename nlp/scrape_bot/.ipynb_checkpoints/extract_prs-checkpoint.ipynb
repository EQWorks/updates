# %%
import json


with open('raw.json') as f:
    data = json.load(f)

data.keys()
# Out:
# dict_keys(['full', 'preview'])

# %%
from bs4 import BeautifulSoup


soup = BeautifulSoup(data['full'], 'html.parser')

# %%
print(soup.prettify())
# Out:
# <p>
#  2 Lone Repo updates
# </p>
# <ul>
#  <li>
#   UNCATEGORIZED -
#   <a href="https://github.com/EQWorks/knowledge-graph" target="_blank">
#    knowledge-graph
#   </a>
#   ,
#   <a href="https://github.com/EQWorks/cog-calculator" target="_blank">
#    cog-calculator
#   </a>
#  </li>
# </ul>
# <p>
#  <br/>
#  51 PR/issues updates
#  <br/>
#  ✔️ Done: 26
#  <br/>
#  ⚠️ WIP: 9
#  <br/>
#  👀 Needs review: 16
# </p>
# <h1>
#  COMMON
# </h1>
# <h2>
#  lumen-table
# </h2>
# <p>
#  (DoParkEQ, kc-leung)
#  <br/>
#  <code>
#   OTHERS
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/lumen-table/issues/18" target="_blank">
#    Issue #18
#   </a>
#   Create filters for quantitave/qualitative data (c: DoParkEQ, a: kc-leung)
#  </li>
# </ul>
# <p>
#  <code>
#   FIXED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/lumen-table/pull/17" target="_blank">
#    PR #17
#   </a>
#   fix overlapped table borders (kc-leung)
#   <ul>
#    <li>
#     <a href="https://github.com/EQWorks/lumen-table/issues/16" target="_blank">
#      Issue #16
#     </a>
#     Table borderline style overlapped
#    </li>
#   </ul>
#  </li>
# </ul>
# <h2>
#  react-maps
# </h2>
# <p>
#  (geoerika, DoParkEQ)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/react-maps/pull/69" target="_blank">
#    PR #69
#   </a>
#   ML Report Map -add legend (geoerika)
#  </li>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/react-maps/pull/68" target="_blank">
#    PR #68
#   </a>
#   heatmap example (DoParkEQ)
#  </li>
# </ul>
# <p>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/react-maps/pull/67" target="_blank">
#    PR #67
#   </a>
#   MlReportMap - add/fix configurations (cursor, tooltip, data-based colour) (geoerika)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/react-maps/pull/66" target="_blank">
#    PR #66
#   </a>
#   Adjust code to work with poi-manage create poi workflow (geoerika)
#  </li>
# </ul>
# <h2>
#  lumen-ui
# </h2>
# <p>
#  (kc-leung)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/lumen-ui/pull/7" target="_blank">
#    PR #7
#   </a>
#   Add color variants to button (kc-leung)
#   <ul>
#    <li>
#     <a href="https://github.com/EQWorks/lumen-ui/issues/6" target="_blank">
#      Issue #6
#     </a>
#     [REQUEST] Add color variants to button
#    </li>
#   </ul>
#  </li>
# </ul>
# <h2>
#  react-labs
# </h2>
# <p>
#  (DoParkEQ)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/react-labs/pull/158" target="_blank">
#    PR #158
#   </a>
#   Modal (DoParkEQ)
#  </li>
# </ul>
# <h2>
#  chart-system
# </h2>
# <p>
#  (DoParkEQ)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/chart-system/pull/126" target="_blank">
#    PR #126
#   </a>
#   VISX/Plotly exp (DoParkEQ)
#  </li>
# </ul>
# <p>
#  <br/>
# </p>
# <h1>
#  HR
# </h1>
# <h2>
#  ws-problems
# </h2>
# <p>
#  (woozyking, DoParkEQ)
#  <br/>
#  <code>
#   OTHERS
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/ws-problems/issues/152" target="_blank">
#    Issue #152
#   </a>
#   candidate/120974984 (c: woozyking, a: geoerika)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/ws-problems/issues/149" target="_blank">
#    Issue #149
#   </a>
#   candidate/101047857 (c: woozyking, a: eq-ianecc)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/ws-problems/issues/148" target="_blank">
#    Issue #148
#   </a>
#   candidate/119182719 (c: woozyking, a: eq-ianecc)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/ws-problems/issues/147" target="_blank">
#    Issue #147
#   </a>
#   candidate/104926210 (woozyking)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/ws-problems/issues/144" target="_blank">
#    Issue #144
#   </a>
#   candidate/101028599 (c: woozyking, a: kevlabs)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/ws-problems/issues/143" target="_blank">
#    Issue #143
#   </a>
#   candidate/121102724 (c: woozyking, a: geoerika)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/ws-problems/issues/136" target="_blank">
#    Issue #136
#   </a>
#   candidate/114029848 (c: woozyking, a: kevlabs)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/ws-problems/issues/98" target="_blank">
#    Issue #98
#   </a>
#   candidate/326212892 (DoParkEQ)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/ws-problems/issues/84" target="_blank">
#    Issue #84
#   </a>
#   candidate/324798300 (DoParkEQ)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/ws-problems/issues/83" target="_blank">
#    Issue #83
#   </a>
#   candidate/324958296 (DoParkEQ)
#  </li>
# </ul>
# <p>
#  <br/>
# </p>
# <h1>
#  LOCUS
# </h1>
# <h2>
#  locussdk
# </h2>
# <p>
#  (woozyking, bsandi1220, maluhoss)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/locussdk/pull/74" target="_blank">
#    PR #74
#   </a>
#   devops - deps, README, and top-level export revisions (woozyking)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/locussdk/pull/68" target="_blank">
#    PR #68
#   </a>
#   get_dataset - update get connection hub data (bsandi1220)
#  </li>
# </ul>
# <p>
#  <code>
#   FIXED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/locussdk/pull/73" target="_blank">
#    PR #73
#   </a>
#   dataset/extra - get time zone geometries (woozyking)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/locussdk/pull/72" target="_blank">
#    PR #72
#   </a>
#   devops - fix dockerfile (bsandi1220)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/locussdk/pull/70" target="_blank">
#    PR #70
#   </a>
#   Use export endpoints when getting LOCUS reports (maluhoss)
#  </li>
# </ul>
# <p>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/locussdk/pull/71" target="_blank">
#    PR #71
#   </a>
#   AOI - add version when saving file (maluhoss)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/locussdk/pull/69" target="_blank">
#    PR #69
#   </a>
#   Dataset - modify ML routes in getting list of datasets (maluhoss)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/locussdk/pull/67" target="_blank">
#    PR #67
#   </a>
#   get_audience - add limit to number of pois (bsandi1220)
#  </li>
# </ul>
# <h2>
#  snoke
# </h2>
# <p>
#  (woozyking, hyx131, YizhiCatherineZhang)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/snoke/pull/946" target="_blank">
#    PR #946
#   </a>
#   hub - new s3 connector based direct upload (woozyking)
#  </li>
# </ul>
# <p>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/snoke/pull/939" target="_blank">
#    PR #939
#   </a>
#   ml - upgrade ml version + react-query version (hyx131)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/snoke/pull/919" target="_blank">
#    PR #919
#   </a>
#   design - change illustrations in home and notebook (YizhiCatherineZhang)
#  </li>
# </ul>
# <h2>
#  firstorder
# </h2>
# <p>
#  (woozyking, maluhoss, kevlabs, bsandi1220)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/firstorder/pull/514" target="_blank">
#    PR #514
#   </a>
#   docs - deployment slash command (woozyking)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/firstorder/pull/512" target="_blank">
#    PR #512
#   </a>
#   devops - docker compose (woozyking)
#  </li>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/firstorder/pull/505" target="_blank">
#    PR #505
#   </a>
#   ML Overhaul - Executions + saved queries (kevlabs)
#  </li>
# </ul>
# <p>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/firstorder/pull/513" target="_blank">
#    PR #513
#   </a>
#   Dataset - create new endpoint to get LOCUS report directly (maluhoss)
#  </li>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/firstorder/pull/511" target="_blank">
#    PR #511
#   </a>
#   Create quick query endpoint for notebook (maluhoss)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/firstorder/pull/510" target="_blank">
#    PR #510
#   </a>
#   Modify report export endpoints to include reqs from notebook (maluhoss)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/firstorder/pull/509" target="_blank">
#    PR #509
#   </a>
#   Report - List reports based on access + new
#   <code>
#    withData
#   </code>
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/firstorder/pull/508" target="_blank">
#    PR #508
#   </a>
#   dataset - add route to get connection hub datasets (bsandi1220)
#  </li>
# </ul>
# <h2>
#  EnrichData
# </h2>
# <p>
#  (maluhoss, bsandi1220)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/EnrichData/pull/38" target="_blank">
#    PR #38
#   </a>
#   Report - create new handler to get LOCUS report directly (maluhoss)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/EnrichData/pull/35" target="_blank">
#    PR #35
#   </a>
#   connectionHub - add get connection method (bsandi1220)
#  </li>
# </ul>
# <p>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/EnrichData/pull/37" target="_blank">
#    PR #37
#   </a>
#   AOI - use geo_id instead of resolution column names (maluhoss)
#  </li>
#  <li>
#   ⚠️
#   <a href="https://github.com/EQWorks/EnrichData/pull/36" target="_blank">
#    PR #36
#   </a>
#   Quick Query util (maluhoss)
#  </li>
# </ul>
# <h2>
#  notebook-files
# </h2>
# <p>
#  (maluhoss)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/notebook-files/pull/9" target="_blank">
#    PR #9
#   </a>
#   AOI file - adjust column names when getting AOI data (maluhoss)
#  </li>
# </ul>
# <p>
#  <br/>
# </p>
# <h1>
#  ATOM
# </h1>
# <h2>
#  overseer
# </h2>
# <p>
#  (kevlabs, woozyking)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/overseer/pull/643" target="_blank">
#    PR #643
#   </a>
#   Insights/GeoCohort - Add new geocohort type (kevlabs)
#  </li>
# </ul>
# <p>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/overseer/pull/642" target="_blank">
#    PR #642
#   </a>
#   docs - add tunnel instruction for docker local dev option (woozyking)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/overseer/pull/641" target="_blank">
#    PR #641
#   </a>
#   devops - add containerization with docker-compose (woozyking)
#  </li>
# </ul>
# <h2>
#  camp-history-writer
# </h2>
# <p>
#  (kevlabs)
#  <br/>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/camp-history-writer/pull/51" target="_blank">
#    PR #51
#   </a>
#   Bids History - Support for geo cohorts + refactor (kevlabs)
#  </li>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/camp-history-writer/pull/50" target="_blank">
#    PR #50
#   </a>
#   Features Writer - Add support for multi dimensions (kevlabs)
#  </li>
# </ul>
# <h2>
#  flash
# </h2>
# <p>
#  (eq-ianecc)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/flash/pull/846" target="_blank">
#    PR #846
#   </a>
#   feature/geo-cohort (eq-ianecc)
#  </li>
# </ul>
# <p>
#  <code>
#   ADDED
#  </code>
# </p>
# <ul>
#  <li>
#   ✔️
#   <a href="https://github.com/EQWorks/flash/pull/845" target="_blank">
#    PR #845
#   </a>
#   adserver - support new AUDIT macro (eq-ianecc)
#  </li>
# </ul>
# <p>
#  <br/>
# </p>
# <h1>
#  UNCATEGORIZED
# </h1>
# <h2>
#  aws_kinesis
# </h2>
# <p>
#  (eq-ianecc)
#  <br/>
#  <code>
#   CHANGED
#  </code>
# </p>
# <ul>
#  <li>
#   👀
#   <a href="https://github.com/EQWorks/aws_kinesis/pull/7" target="_blank">
#    PR #7
#   </a>
#   geo cohort fields (eq-ianecc)
#  </li>
# </ul>
# <p>
#  <br/>
# </p>

# %%
import pandas as pd

def item_filter(tag):
    cond = tag.name == 'li'
    cond = cond and 'PR' in tag.text
    cond = cond and tag.find('a').get('href')
    return cond


data = []
for it in soup.find_all(item_filter):
    data.append({
        'text': it.text,
        'link': it.find('a').get('href'),
    })
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                  text  \
# 0   ⚠️ PR #17 fix overlapped table borders (kc-leu...
# 1      ⚠️ PR #69 ML Report Map -add legend (geoerika)
# 2                ⚠️ PR #68 heatmap example (DoParkEQ)
# 3   ✔️ PR #67 MlReportMap - add/fix configurations...
# 4   ✔️ PR #66 Adjust code to work with poi-manage ...
# 5   ✔️ PR #7 Add color variants to button (kc-leun...
# 6                         ✔️ PR #158 Modal (DoParkEQ)
# 7               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 8   👀 PR #74 devops - deps, README, and top-level ...
# 9   ✔️ PR #68 get_dataset - update get connection ...
# 10  ⚠️ PR #73 dataset/extra - get time zone geomet...
# 11     ✔️ PR #72 devops - fix dockerfile (bsandi1220)
# 12  👀 PR #70 Use export endpoints when getting LOC...
# 13  ✔️ PR #71 AOI - add version when saving file (...
# 14  👀 PR #69 Dataset - modify ML routes in getting...
# 15  ✔️ PR #67 get_audience - add limit to number o...
# 16  👀 PR #946 hub - new s3 connector based direct ...
# 17  ⚠️ PR #939 ml - upgrade ml version + react-que...
# 18  👀 PR #919 design - change illustrations in hom...
# 19  ✔️ PR #514 docs - deployment slash command (wo...
# 20     ✔️ PR #512 devops - docker compose (woozyking)
# 21  👀 PR #505 ML Overhaul - Executions + saved que...
# 22  👀 PR #513 Dataset - create new endpoint to get...
# 23  ⚠️ PR #511 Create quick query endpoint for not...
# 24  ✔️ PR #510 Modify report export endpoints to i...
# 25  ✔️ PR #509 Report - List reports based on acce...
# 26  ✔️ PR #508 dataset - add route to get connecti...
# 27  ⚠️ PR #38 Report - create new handler to get L...
# 28  ✔️ PR #35 connectionHub - add get connection m...
# 29  ✔️ PR #37 AOI - use geo_id instead of resoluti...
# 30              ⚠️ PR #36 Quick Query util (maluhoss)
# 31  ✔️ PR #9 AOI file - adjust column names when g...
# 32  ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 33  👀 PR #642 docs - add tunnel instruction for do...
# 34  ✔️ PR #641 devops - add containerization with ...
# 35  ✔️ PR #51 Bids History - Support for geo cohor...
# 36  ✔️ PR #50 Features Writer - Add support for mu...
# 37           👀 PR #846 feature/geo-cohort (eq-ianecc)
# 38  ✔️ PR #845 adserver - support new AUDIT macro ...
# 39              👀 PR #7 geo cohort fields (eq-ianecc)
#
#                                                  link
# 0      https://github.com/EQWorks/lumen-table/pull/17
# 1       https://github.com/EQWorks/react-maps/pull/69
# 2       https://github.com/EQWorks/react-maps/pull/68
# 3       https://github.com/EQWorks/react-maps/pull/67
# 4       https://github.com/EQWorks/react-maps/pull/66
# 5          https://github.com/EQWorks/lumen-ui/pull/7
# 6      https://github.com/EQWorks/react-labs/pull/158
# 7    https://github.com/EQWorks/chart-system/pull/126
# 8         https://github.com/EQWorks/locussdk/pull/74
# 9         https://github.com/EQWorks/locussdk/pull/68
# 10        https://github.com/EQWorks/locussdk/pull/73
# 11        https://github.com/EQWorks/locussdk/pull/72
# 12        https://github.com/EQWorks/locussdk/pull/70
# 13        https://github.com/EQWorks/locussdk/pull/71
# 14        https://github.com/EQWorks/locussdk/pull/69
# 15        https://github.com/EQWorks/locussdk/pull/67
# 16          https://github.com/EQWorks/snoke/pull/946
# 17          https://github.com/EQWorks/snoke/pull/939
# 18          https://github.com/EQWorks/snoke/pull/919
# 19     https://github.com/EQWorks/firstorder/pull/514
# 20     https://github.com/EQWorks/firstorder/pull/512
# 21     https://github.com/EQWorks/firstorder/pull/505
# 22     https://github.com/EQWorks/firstorder/pull/513
# 23     https://github.com/EQWorks/firstorder/pull/511
# 24     https://github.com/EQWorks/firstorder/pull/510
# 25     https://github.com/EQWorks/firstorder/pull/509
# 26     https://github.com/EQWorks/firstorder/pull/508
# 27      https://github.com/EQWorks/EnrichData/pull/38
# 28      https://github.com/EQWorks/EnrichData/pull/35
# 29      https://github.com/EQWorks/EnrichData/pull/37
# 30      https://github.com/EQWorks/EnrichData/pull/36
# 31   https://github.com/EQWorks/notebook-files/pull/9
# 32       https://github.com/EQWorks/overseer/pull/643
# 33       https://github.com/EQWorks/overseer/pull/642
# 34       https://github.com/EQWorks/overseer/pull/641
# 35  https://github.com/EQWorks/camp-history-writer...
# 36  https://github.com/EQWorks/camp-history-writer...
# 37          https://github.com/EQWorks/flash/pull/846
# 38          https://github.com/EQWorks/flash/pull/845
# 39      https://github.com/EQWorks/aws_kinesis/pull/7

# %%
state_map = {
    '⚠': 'wip',
    '👀': 'needs review',
    '✔': 'done',
}

df['state'] = df.text.apply(lambda x: state_map[x[0]])
df
# Out:
#                                                  text  \
# 0   ⚠️ PR #17 fix overlapped table borders (kc-leu...
# 1      ⚠️ PR #69 ML Report Map -add legend (geoerika)
# 2                ⚠️ PR #68 heatmap example (DoParkEQ)
# 3   ✔️ PR #67 MlReportMap - add/fix configurations...
# 4   ✔️ PR #66 Adjust code to work with poi-manage ...
# 5   ✔️ PR #7 Add color variants to button (kc-leun...
# 6                         ✔️ PR #158 Modal (DoParkEQ)
# 7               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 8   👀 PR #74 devops - deps, README, and top-level ...
# 9   ✔️ PR #68 get_dataset - update get connection ...
# 10  ⚠️ PR #73 dataset/extra - get time zone geomet...
# 11     ✔️ PR #72 devops - fix dockerfile (bsandi1220)
# 12  👀 PR #70 Use export endpoints when getting LOC...
# 13  ✔️ PR #71 AOI - add version when saving file (...
# 14  👀 PR #69 Dataset - modify ML routes in getting...
# 15  ✔️ PR #67 get_audience - add limit to number o...
# 16  👀 PR #946 hub - new s3 connector based direct ...
# 17  ⚠️ PR #939 ml - upgrade ml version + react-que...
# 18  👀 PR #919 design - change illustrations in hom...
# 19  ✔️ PR #514 docs - deployment slash command (wo...
# 20     ✔️ PR #512 devops - docker compose (woozyking)
# 21  👀 PR #505 ML Overhaul - Executions + saved que...
# 22  👀 PR #513 Dataset - create new endpoint to get...
# 23  ⚠️ PR #511 Create quick query endpoint for not...
# 24  ✔️ PR #510 Modify report export endpoints to i...
# 25  ✔️ PR #509 Report - List reports based on acce...
# 26  ✔️ PR #508 dataset - add route to get connecti...
# 27  ⚠️ PR #38 Report - create new handler to get L...
# 28  ✔️ PR #35 connectionHub - add get connection m...
# 29  ✔️ PR #37 AOI - use geo_id instead of resoluti...
# 30              ⚠️ PR #36 Quick Query util (maluhoss)
# 31  ✔️ PR #9 AOI file - adjust column names when g...
# 32  ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 33  👀 PR #642 docs - add tunnel instruction for do...
# 34  ✔️ PR #641 devops - add containerization with ...
# 35  ✔️ PR #51 Bids History - Support for geo cohor...
# 36  ✔️ PR #50 Features Writer - Add support for mu...
# 37           👀 PR #846 feature/geo-cohort (eq-ianecc)
# 38  ✔️ PR #845 adserver - support new AUDIT macro ...
# 39              👀 PR #7 geo cohort fields (eq-ianecc)
#
#                                                  link         state
# 0      https://github.com/EQWorks/lumen-table/pull/17           wip
# 1       https://github.com/EQWorks/react-maps/pull/69           wip
# 2       https://github.com/EQWorks/react-maps/pull/68           wip
# 3       https://github.com/EQWorks/react-maps/pull/67          done
# 4       https://github.com/EQWorks/react-maps/pull/66          done
# 5          https://github.com/EQWorks/lumen-ui/pull/7          done
# 6      https://github.com/EQWorks/react-labs/pull/158          done
# 7    https://github.com/EQWorks/chart-system/pull/126           wip
# 8         https://github.com/EQWorks/locussdk/pull/74  needs review
# 9         https://github.com/EQWorks/locussdk/pull/68          done
# 10        https://github.com/EQWorks/locussdk/pull/73           wip
# 11        https://github.com/EQWorks/locussdk/pull/72          done
# 12        https://github.com/EQWorks/locussdk/pull/70  needs review
# 13        https://github.com/EQWorks/locussdk/pull/71          done
# 14        https://github.com/EQWorks/locussdk/pull/69  needs review
# 15        https://github.com/EQWorks/locussdk/pull/67          done
# 16          https://github.com/EQWorks/snoke/pull/946  needs review
# 17          https://github.com/EQWorks/snoke/pull/939           wip
# 18          https://github.com/EQWorks/snoke/pull/919  needs review
# 19     https://github.com/EQWorks/firstorder/pull/514          done
# 20     https://github.com/EQWorks/firstorder/pull/512          done
# 21     https://github.com/EQWorks/firstorder/pull/505  needs review
# 22     https://github.com/EQWorks/firstorder/pull/513  needs review
# 23     https://github.com/EQWorks/firstorder/pull/511           wip
# 24     https://github.com/EQWorks/firstorder/pull/510          done
# 25     https://github.com/EQWorks/firstorder/pull/509          done
# 26     https://github.com/EQWorks/firstorder/pull/508          done
# 27      https://github.com/EQWorks/EnrichData/pull/38           wip
# 28      https://github.com/EQWorks/EnrichData/pull/35          done
# 29      https://github.com/EQWorks/EnrichData/pull/37          done
# 30      https://github.com/EQWorks/EnrichData/pull/36           wip
# 31   https://github.com/EQWorks/notebook-files/pull/9          done
# 32       https://github.com/EQWorks/overseer/pull/643          done
# 33       https://github.com/EQWorks/overseer/pull/642  needs review
# 34       https://github.com/EQWorks/overseer/pull/641          done
# 35  https://github.com/EQWorks/camp-history-writer...          done
# 36  https://github.com/EQWorks/camp-history-writer...          done
# 37          https://github.com/EQWorks/flash/pull/846  needs review
# 38          https://github.com/EQWorks/flash/pull/845          done
# 39      https://github.com/EQWorks/aws_kinesis/pull/7  needs review

# %%
def extract_contributors(text):
    contributors = text.split('(')[-1].split(')')[0]
    if text == contributors:
        return ''
    return contributors

df['contributors'] = df.text.apply(extract_contributors)
df
# Out:
#                                                  text  \
# 0   ⚠️ PR #17 fix overlapped table borders (kc-leu...
# 1      ⚠️ PR #69 ML Report Map -add legend (geoerika)
# 2                ⚠️ PR #68 heatmap example (DoParkEQ)
# 3   ✔️ PR #67 MlReportMap - add/fix configurations...
# 4   ✔️ PR #66 Adjust code to work with poi-manage ...
# 5   ✔️ PR #7 Add color variants to button (kc-leun...
# 6                         ✔️ PR #158 Modal (DoParkEQ)
# 7               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 8   👀 PR #74 devops - deps, README, and top-level ...
# 9   ✔️ PR #68 get_dataset - update get connection ...
# 10  ⚠️ PR #73 dataset/extra - get time zone geomet...
# 11     ✔️ PR #72 devops - fix dockerfile (bsandi1220)
# 12  👀 PR #70 Use export endpoints when getting LOC...
# 13  ✔️ PR #71 AOI - add version when saving file (...
# 14  👀 PR #69 Dataset - modify ML routes in getting...
# 15  ✔️ PR #67 get_audience - add limit to number o...
# 16  👀 PR #946 hub - new s3 connector based direct ...
# 17  ⚠️ PR #939 ml - upgrade ml version + react-que...
# 18  👀 PR #919 design - change illustrations in hom...
# 19  ✔️ PR #514 docs - deployment slash command (wo...
# 20     ✔️ PR #512 devops - docker compose (woozyking)
# 21  👀 PR #505 ML Overhaul - Executions + saved que...
# 22  👀 PR #513 Dataset - create new endpoint to get...
# 23  ⚠️ PR #511 Create quick query endpoint for not...
# 24  ✔️ PR #510 Modify report export endpoints to i...
# 25  ✔️ PR #509 Report - List reports based on acce...
# 26  ✔️ PR #508 dataset - add route to get connecti...
# 27  ⚠️ PR #38 Report - create new handler to get L...
# 28  ✔️ PR #35 connectionHub - add get connection m...
# 29  ✔️ PR #37 AOI - use geo_id instead of resoluti...
# 30              ⚠️ PR #36 Quick Query util (maluhoss)
# 31  ✔️ PR #9 AOI file - adjust column names when g...
# 32  ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 33  👀 PR #642 docs - add tunnel instruction for do...
# 34  ✔️ PR #641 devops - add containerization with ...
# 35  ✔️ PR #51 Bids History - Support for geo cohor...
# 36  ✔️ PR #50 Features Writer - Add support for mu...
# 37           👀 PR #846 feature/geo-cohort (eq-ianecc)
# 38  ✔️ PR #845 adserver - support new AUDIT macro ...
# 39              👀 PR #7 geo cohort fields (eq-ianecc)
#
#                                                  link         state  \
# 0      https://github.com/EQWorks/lumen-table/pull/17           wip
# 1       https://github.com/EQWorks/react-maps/pull/69           wip
# 2       https://github.com/EQWorks/react-maps/pull/68           wip
# 3       https://github.com/EQWorks/react-maps/pull/67          done
# 4       https://github.com/EQWorks/react-maps/pull/66          done
# 5          https://github.com/EQWorks/lumen-ui/pull/7          done
# 6      https://github.com/EQWorks/react-labs/pull/158          done
# 7    https://github.com/EQWorks/chart-system/pull/126           wip
# 8         https://github.com/EQWorks/locussdk/pull/74  needs review
# 9         https://github.com/EQWorks/locussdk/pull/68          done
# 10        https://github.com/EQWorks/locussdk/pull/73           wip
# 11        https://github.com/EQWorks/locussdk/pull/72          done
# 12        https://github.com/EQWorks/locussdk/pull/70  needs review
# 13        https://github.com/EQWorks/locussdk/pull/71          done
# 14        https://github.com/EQWorks/locussdk/pull/69  needs review
# 15        https://github.com/EQWorks/locussdk/pull/67          done
# 16          https://github.com/EQWorks/snoke/pull/946  needs review
# 17          https://github.com/EQWorks/snoke/pull/939           wip
# 18          https://github.com/EQWorks/snoke/pull/919  needs review
# 19     https://github.com/EQWorks/firstorder/pull/514          done
# 20     https://github.com/EQWorks/firstorder/pull/512          done
# 21     https://github.com/EQWorks/firstorder/pull/505  needs review
# 22     https://github.com/EQWorks/firstorder/pull/513  needs review
# 23     https://github.com/EQWorks/firstorder/pull/511           wip
# 24     https://github.com/EQWorks/firstorder/pull/510          done
# 25     https://github.com/EQWorks/firstorder/pull/509          done
# 26     https://github.com/EQWorks/firstorder/pull/508          done
# 27      https://github.com/EQWorks/EnrichData/pull/38           wip
# 28      https://github.com/EQWorks/EnrichData/pull/35          done
# 29      https://github.com/EQWorks/EnrichData/pull/37          done
# 30      https://github.com/EQWorks/EnrichData/pull/36           wip
# 31   https://github.com/EQWorks/notebook-files/pull/9          done
# 32       https://github.com/EQWorks/overseer/pull/643          done
# 33       https://github.com/EQWorks/overseer/pull/642  needs review
# 34       https://github.com/EQWorks/overseer/pull/641          done
# 35  https://github.com/EQWorks/camp-history-writer...          done
# 36  https://github.com/EQWorks/camp-history-writer...          done
# 37          https://github.com/EQWorks/flash/pull/846  needs review
# 38          https://github.com/EQWorks/flash/pull/845          done
# 39      https://github.com/EQWorks/aws_kinesis/pull/7  needs review
#
#            contributors
# 0              kc-leung
# 1              geoerika
# 2              DoParkEQ
# 3              geoerika
# 4              geoerika
# 5              kc-leung
# 6              DoParkEQ
# 7              DoParkEQ
# 8             woozyking
# 9            bsandi1220
# 10            woozyking
# 11           bsandi1220
# 12             maluhoss
# 13             maluhoss
# 14             maluhoss
# 15           bsandi1220
# 16            woozyking
# 17               hyx131
# 18  YizhiCatherineZhang
# 19            woozyking
# 20            woozyking
# 21              kevlabs
# 22             maluhoss
# 23             maluhoss
# 24             maluhoss
# 25
# 26           bsandi1220
# 27             maluhoss
# 28           bsandi1220
# 29             maluhoss
# 30             maluhoss
# 31             maluhoss
# 32              kevlabs
# 33            woozyking
# 34            woozyking
# 35              kevlabs
# 36              kevlabs
# 37            eq-ianecc
# 38            eq-ianecc
# 39            eq-ianecc

# %%
df.iloc[25].text
# Out:
# '✔️ PR #509 Report - List reports based on access + new withData'

# %%
def clean(text):
    _, _, _, text = text.split(' ', maxsplit=3)
    text = text.split('(')[0]
    return text

df['text_cleaned'] = df.text.apply(clean)
df
# Out:
#                                                  text  \
# 0   ⚠️ PR #17 fix overlapped table borders (kc-leu...
# 1      ⚠️ PR #69 ML Report Map -add legend (geoerika)
# 2                ⚠️ PR #68 heatmap example (DoParkEQ)
# 3   ✔️ PR #67 MlReportMap - add/fix configurations...
# 4   ✔️ PR #66 Adjust code to work with poi-manage ...
# 5   ✔️ PR #7 Add color variants to button (kc-leun...
# 6                         ✔️ PR #158 Modal (DoParkEQ)
# 7               ⚠️ PR #126 VISX/Plotly exp (DoParkEQ)
# 8   👀 PR #74 devops - deps, README, and top-level ...
# 9   ✔️ PR #68 get_dataset - update get connection ...
# 10  ⚠️ PR #73 dataset/extra - get time zone geomet...
# 11     ✔️ PR #72 devops - fix dockerfile (bsandi1220)
# 12  👀 PR #70 Use export endpoints when getting LOC...
# 13  ✔️ PR #71 AOI - add version when saving file (...
# 14  👀 PR #69 Dataset - modify ML routes in getting...
# 15  ✔️ PR #67 get_audience - add limit to number o...
# 16  👀 PR #946 hub - new s3 connector based direct ...
# 17  ⚠️ PR #939 ml - upgrade ml version + react-que...
# 18  👀 PR #919 design - change illustrations in hom...
# 19  ✔️ PR #514 docs - deployment slash command (wo...
# 20     ✔️ PR #512 devops - docker compose (woozyking)
# 21  👀 PR #505 ML Overhaul - Executions + saved que...
# 22  👀 PR #513 Dataset - create new endpoint to get...
# 23  ⚠️ PR #511 Create quick query endpoint for not...
# 24  ✔️ PR #510 Modify report export endpoints to i...
# 25  ✔️ PR #509 Report - List reports based on acce...
# 26  ✔️ PR #508 dataset - add route to get connecti...
# 27  ⚠️ PR #38 Report - create new handler to get L...
# 28  ✔️ PR #35 connectionHub - add get connection m...
# 29  ✔️ PR #37 AOI - use geo_id instead of resoluti...
# 30              ⚠️ PR #36 Quick Query util (maluhoss)
# 31  ✔️ PR #9 AOI file - adjust column names when g...
# 32  ✔️ PR #643 Insights/GeoCohort - Add new geocoh...
# 33  👀 PR #642 docs - add tunnel instruction for do...
# 34  ✔️ PR #641 devops - add containerization with ...
# 35  ✔️ PR #51 Bids History - Support for geo cohor...
# 36  ✔️ PR #50 Features Writer - Add support for mu...
# 37           👀 PR #846 feature/geo-cohort (eq-ianecc)
# 38  ✔️ PR #845 adserver - support new AUDIT macro ...
# 39              👀 PR #7 geo cohort fields (eq-ianecc)
#
#                                                  link         state  \
# 0      https://github.com/EQWorks/lumen-table/pull/17           wip
# 1       https://github.com/EQWorks/react-maps/pull/69           wip
# 2       https://github.com/EQWorks/react-maps/pull/68           wip
# 3       https://github.com/EQWorks/react-maps/pull/67          done
# 4       https://github.com/EQWorks/react-maps/pull/66          done
# 5          https://github.com/EQWorks/lumen-ui/pull/7          done
# 6      https://github.com/EQWorks/react-labs/pull/158          done
# 7    https://github.com/EQWorks/chart-system/pull/126           wip
# 8         https://github.com/EQWorks/locussdk/pull/74  needs review
# 9         https://github.com/EQWorks/locussdk/pull/68          done
# 10        https://github.com/EQWorks/locussdk/pull/73           wip
# 11        https://github.com/EQWorks/locussdk/pull/72          done
# 12        https://github.com/EQWorks/locussdk/pull/70  needs review
# 13        https://github.com/EQWorks/locussdk/pull/71          done
# 14        https://github.com/EQWorks/locussdk/pull/69  needs review
# 15        https://github.com/EQWorks/locussdk/pull/67          done
# 16          https://github.com/EQWorks/snoke/pull/946  needs review
# 17          https://github.com/EQWorks/snoke/pull/939           wip
# 18          https://github.com/EQWorks/snoke/pull/919  needs review
# 19     https://github.com/EQWorks/firstorder/pull/514          done
# 20     https://github.com/EQWorks/firstorder/pull/512          done
# 21     https://github.com/EQWorks/firstorder/pull/505  needs review
# 22     https://github.com/EQWorks/firstorder/pull/513  needs review
# 23     https://github.com/EQWorks/firstorder/pull/511           wip
# 24     https://github.com/EQWorks/firstorder/pull/510          done
# 25     https://github.com/EQWorks/firstorder/pull/509          done
# 26     https://github.com/EQWorks/firstorder/pull/508          done
# 27      https://github.com/EQWorks/EnrichData/pull/38           wip
# 28      https://github.com/EQWorks/EnrichData/pull/35          done
# 29      https://github.com/EQWorks/EnrichData/pull/37          done
# 30      https://github.com/EQWorks/EnrichData/pull/36           wip
# 31   https://github.com/EQWorks/notebook-files/pull/9          done
# 32       https://github.com/EQWorks/overseer/pull/643          done
# 33       https://github.com/EQWorks/overseer/pull/642  needs review
# 34       https://github.com/EQWorks/overseer/pull/641          done
# 35  https://github.com/EQWorks/camp-history-writer...          done
# 36  https://github.com/EQWorks/camp-history-writer...          done
# 37          https://github.com/EQWorks/flash/pull/846  needs review
# 38          https://github.com/EQWorks/flash/pull/845          done
# 39      https://github.com/EQWorks/aws_kinesis/pull/7  needs review
#
#            contributors                                       text_cleaned
# 0              kc-leung                      fix overlapped table borders
# 1              geoerika                         ML Report Map -add legend
# 2              DoParkEQ                                   heatmap example
# 3              geoerika              MlReportMap - add/fix configurations
# 4              geoerika  Adjust code to work with poi-manage create poi...
# 5              kc-leung                      Add color variants to button
# 6              DoParkEQ                                             Modal
# 7              DoParkEQ                                   VISX/Plotly exp
# 8             woozyking  devops - deps, README, and top-level export re...
# 9            bsandi1220      get_dataset - update get connection hub data
# 10            woozyking          dataset/extra - get time zone geometries
# 11           bsandi1220                           devops - fix dockerfile
# 12             maluhoss   Use export endpoints when getting LOCUS reports
# 13             maluhoss                AOI - add version when saving file
# 14             maluhoss  Dataset - modify ML routes in getting list of ...
# 15           bsandi1220        get_audience - add limit to number of pois
# 16            woozyking        hub - new s3 connector based direct upload
# 17               hyx131     ml - upgrade ml version + react-query version
# 18  YizhiCatherineZhang  design - change illustrations in home and note...
# 19            woozyking                   docs - deployment slash command
# 20            woozyking                           devops - docker compose
# 21              kevlabs          ML Overhaul - Executions + saved queries
# 22             maluhoss  Dataset - create new endpoint to get LOCUS rep...
# 23             maluhoss          Create quick query endpoint for notebook
# 24             maluhoss  Modify report export endpoints to include reqs...
# 25                       Report - List reports based on access + new wi...
# 26           bsandi1220  dataset - add route to get connection hub data...
# 27             maluhoss  Report - create new handler to get LOCUS repor...
# 28           bsandi1220         connectionHub - add get connection method
# 29             maluhoss  AOI - use geo_id instead of resolution column ...
# 30             maluhoss                                  Quick Query util
# 31             maluhoss  AOI file - adjust column names when getting AO...
# 32              kevlabs       Insights/GeoCohort - Add new geocohort type
# 33            woozyking  docs - add tunnel instruction for docker local...
# 34            woozyking  devops - add containerization with docker-comp...
# 35              kevlabs  Bids History - Support for geo cohorts + refac...
# 36              kevlabs  Features Writer - Add support for multi dimens...
# 37            eq-ianecc                                feature/geo-cohort
# 38            eq-ianecc                adserver - support new AUDIT macro
# 39            eq-ianecc                                 geo cohort fields
